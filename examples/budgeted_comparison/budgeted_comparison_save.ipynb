# %% [markdown]
# # Budgeted MLMC vs MLQMC

# %% [markdown]
# ## Imports

# %%
import mlqmcpy as mp
from mlqmcpy.problems import analytic, elliptic, asian_option, borehole

# %%
import numpy as np
import scipy.stats
import qmcpy as qp
import time
import os
import gc

# %%
import matplotlib 
from matplotlib import pyplot
pyplot.style.use("seaborn-v0_8-whitegrid")
COLORS = ['xkcd:purple', 'xkcd:green', 'xkcd:blue', 'xkcd:red', 'xkcd:turquoise', 'xkcd:pink', 'xkcd:brown', 'xkcd:light blue', 'xkcd:teal', 'xkcd:orange']
#pyplot.rcParams['axes.prop_cycle'] = matplotlib.cycler(color=COLORS)
WIDTH = 2*(500/72)
LW = 3
alpha = .2

# %%
from IPython.display import display, HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %% [markdown]
# ## Experiment

# %%
force_experiment = False
#problem_dim_levels = (analytic,2,10)
#problem_dim_levels = (borehole,8,2)
problem_dim_levels = (elliptic,8,4)
#problem_dim_levels = (asian_option,16,8)
problem,dimension,num_levels = problem_dim_levels
dataroot = "budgeted_comparison_data/comp.%s.d%d.levels%d.DNET.FULL/"%(problem.__name__,dimension,num_levels)
if not os.path.exists(dataroot): os.makedirs(dataroot)
if not os.path.isfile(dataroot+"data.npy") or force_experiment:
    # parameters 
    max_budgets = 2**np.arange(7,12)
    initial_cost_prop_max_budget = 1/4
    kwargs_fastgp_fit = {"loss_metric":"MLL","stop_crit_improvement_threshold":1e0,"verbose":0}
    refit_igps = True
    refit_mtgps = True
    n_ref = 2**19
    trials = 50
    verbose = max(1,trials//10)
    zip_name_IteratorClass_kwargs = [
        ## MLMC
        ("MLMC    IID",mp.GreedyMLMCIterator,{}),
        ## R-MLQMC
        # ##  LATTICE
        # ("R-MLQMC Lattice",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"replications":8}),
        # ("R-MLQMC Lattice",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"replications":16}),
        # ("R-MLQMC Lattice",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"replications":32}),
        # ("R-MLQMC Lattice",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"replications":64}),
        ##  DNET 
        ("R-MLQMC DNet",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"replications":8}),
        ("R-MLQMC DNet",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"replications":16}),
        ("R-MLQMC DNet",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"replications":32}),
        ("R-MLQMC DNet",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"replications":64}),
        ## IGP 
        ##   FAST
        # ##       LATTICE 
        # (r"IGP    Lattice  Fast  SI  $\alpha=2$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"kwargs_fastgp_construct":{"alpha":2},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # (r"IGP    Lattice  Fast  SI  $\alpha=3$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"kwargs_fastgp_construct":{"alpha":3},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # (r"IGP    Lattice  Fast  SI  $\alpha=4$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"kwargs_fastgp_construct":{"alpha":4},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # (r"IGP    Lattice  Fast  SI  $\alpha=5$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"kwargs_fastgp_construct":{"alpha":5},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        ##       DNET
        (r"IGP    DNet     Fast  DSI $\alpha=1$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"kwargs_fastgp_construct":{"alpha":1},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        (r"IGP    DNet     Fast  DSI $\alpha=2$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"kwargs_fastgp_construct":{"alpha":2},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        (r"IGP    DNet     Fast  DSI $\alpha=3$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"kwargs_fastgp_construct":{"alpha":3},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        (r"IGP    DNet     Fast  DSI $\alpha=4$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"kwargs_fastgp_construct":{"alpha":4},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # ##   SLOW        
        # ##       Lattice
        # (r"IGP    Lattice  Slow  SE",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":False,"kwargs_fastgp_construct":{},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # ##       DNET 
        # (r"IGP    DNet     Slow  SE",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":False,"kwargs_fastgp_construct":{},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        ## MTGP
        ##   FAST 
        # ##       LATTICE
        # (r"MTGP   Lattice  Fast  SI  $\alpha=2$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":2,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # (r"MTGP   Lattice  Fast  SI  $\alpha=3$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":3,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # (r"MTGP   Lattice  Fast  SI  $\alpha=4$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":4,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # (r"MTGP   Lattice  Fast  SI  $\alpha=5$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":5,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        ##       DNET
        (r"MTGP   DNet     Fast  DSI $\alpha=1$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":1,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        (r"MTGP   DNet     Fast  DSI $\alpha=2$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":2,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        (r"MTGP   DNet     Fast  DSI $\alpha=3$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":3,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        (r"MTGP   DNet     Fast  DSI $\alpha=4$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":4,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # ##   SLOW
        # ##       LATTICE
        # (r"MTGP   Lattice  Slow  SE",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":False,"budget_scheme":"greedy","kwargs_fastgp_construct":{"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit},"refit_gps":refit_mtgps),
        # ##       DNET
        # (r"MTGP   DNet     Slow  SE",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":False,"budget_scheme":"greedy","kwargs_fastgp_construct":{"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit},"refit_gps":refit_mtgps),
    ]
    # experiment
    t0 = time.perf_counter()
    names = [name for (name,IteratorClass,kwargs) in zip_name_IteratorClass_kwargs]
    if hasattr(problem,"exact") and hasattr(problem.exact,"Q") and hasattr(problem.exact.Q,"mean"):
        true_solution = problem.exact.Q.mean(level=num_levels-1)
    else:
        true_solution = problem(num_levels-1,qp.DigitalNetB2(dimension)(n_ref)).mean()
    cost_per_level = 2.**(np.arange(num_levels)-num_levels+1) # Rescale so that finest level has unit cost
    print("max_budgets: %s"%max_budgets)
    print("cost_per_level: %s"%str(cost_per_level))
    print("true_solution = %.5e"%true_solution)
    print()
    costs = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials))
    means = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials))
    std_errors = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials))
    true_errors = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials))
    samples_per_level = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials,num_levels),dtype=int)
    for j in range(len(max_budgets)):
        max_budget = max_budgets[j]
        initial_budget = int(initial_cost_prop_max_budget*max_budget)
        print("budget = %d, initial budget = %d"%(max_budget,initial_budget))
        initial_sample_size_og = initial_budget/num_levels/cost_per_level
        for i,(name,IteratorClass,kwargs) in enumerate(zip_name_IteratorClass_kwargs):
            if IteratorClass==mp.GreedyMLQMCIterator:
                initial_sample_size = initial_sample_size_og/kwargs["replications"]
                initial_sample_size = 2**np.ceil(np.log2(initial_sample_size)).astype(int)
                initial_cost = kwargs["replications"]*(initial_sample_size*cost_per_level).sum()
            else:
                initial_sample_size = 2**np.ceil(np.log2(initial_sample_size_og)).astype(int)
                initial_cost = (initial_sample_size*cost_per_level).sum()
            print("\t%s, \t initial_sample_size = %s, \tinitial cost = %.1f"%(name,str(initial_sample_size.tolist()),initial_cost))
            for t in range(trials):
                iterator = IteratorClass(
                    dimension,
                    initial_sample_size = initial_sample_size,
                    cost_per_level = cost_per_level,
                    max_budget = max_budget,
                    **kwargs)
                problem_l_or_ml = problem if isinstance(iterator,mp.MultiTaskGaussianProcessMLQMCIterator) else problem.ml
                problem_tf = (lambda level,x: problem_l_or_ml(level,1-2*np.abs(x-1/2))) if iterator.discrete_distribution_type==qp.Lattice else problem_l_or_ml
                for iter, new_samples in enumerate(iterator):
                    new_results = {level: problem_tf(level,samples) for level,samples in new_samples.items()}
                    iterator.update(new_results)
                costs[i,j,t] = iterator.cost
                means[i,j,t] = iterator.mean
                std_errors[i,j,t] = iterator.standard_error
                true_errors[i,j,t] = np.abs(true_solution-means[i,j,t])
                samples_per_level[i,j,t] = iterator.total_samples_per_level.copy()
                if verbose and t%verbose==0:
                    print("\t\ttrial: %-6d iteration: %-6d cost: %-10d mean: %-15.3e std error: %-15.3e true error: %-15.3e time %-15d sample sizes %s"%\
                    (t,iter,costs[i,j,t],means[i,j,t],std_errors[i,j,t],true_errors[i,j,t],int(np.ceil(time.perf_counter()-t0)),str(samples_per_level[i,j,t].tolist())))
                #import psutil; process = psutil.Process(os.getpid()); print(f"Total program memory: {process.memory_info().rss / (1024 * 1024):.2f} MB")
        print()
    data = {
        "dimension": dimension,
        "num_levels": num_levels,
        "max_budgets": max_budgets,
        "initial_cost_prop_max_budget": initial_cost_prop_max_budget,
        "names": names,
        "costs": costs,
        "means": means,
        "std_errors": std_errors,
        "true_errors": true_errors,
        "kwargs_fastgp_fit": kwargs_fastgp_fit,
        "refit_gps":refit_igps,
        "n_ref":n_ref,
    }
    np.save(dataroot+"data.npy",data)
else:
    data = np.load(dataroot+"data.npy",allow_pickle=True)[()]
    dimension = data["dimension"]
    num_levels = data["num_levels"]
    initial_cost_prop_max_budget = data["initial_cost_prop_max_budget"]
    max_budgets = data["max_budgets"]
    names = data["names"]
    costs = data["costs"]
    means = data["means"]
    std_errors = data["std_errors"]
    true_errors = data["true_errors"]
    kwargs_fastgp_fit = data["kwargs_fastgp_fit"]
    refit_igps = data["refit_gps"]
    n_ref = data["n_ref"]
    trials = costs.shape[-1]
# Out:
# max_budgets: [ 128  256  512 1024 2048]
# cost_per_level: [0.125 0.25  0.5   1.   ]
# true_solution = 1.49938e-01
#
# budget = 128, initial budget = 32
# 	MLMC    IID, 	 initial_sample_size = [64, 32, 16, 8], 	initial cost = 32.0
# 		trial: 0      iteration: 7      cost: 128        mean: 1.453e-01       std error: 7.327e-03       true error: 4.603e-03       time 33              sample sizes [512, 128, 32, 16]
# 		trial: 5      iteration: 7      cost: 128        mean: 1.498e-01       std error: 9.768e-03       true error: 9.643e-05       time 33              sample sizes [512, 128, 32, 16]
# 		trial: 10     iteration: 7      cost: 128        mean: 1.642e-01       std error: 9.002e-03       true error: 1.422e-02       time 33              sample sizes [512, 128, 32, 16]
# 		trial: 15     iteration: 7      cost: 128        mean: 1.518e-01       std error: 8.245e-03       true error: 1.897e-03       time 33              sample sizes [512, 128, 32, 16]
# 		trial: 20     iteration: 7      cost: 128        mean: 1.462e-01       std error: 7.719e-03       true error: 3.773e-03       time 34              sample sizes [512, 128, 32, 16]
# 		trial: 25     iteration: 7      cost: 128        mean: 1.396e-01       std error: 1.015e-02       true error: 1.030e-02       time 34              sample sizes [512, 128, 32, 16]
# 		trial: 30     iteration: 7      cost: 128        mean: 1.522e-01       std error: 7.619e-03       true error: 2.270e-03       time 34              sample sizes [512, 128, 32, 16]
# 		trial: 35     iteration: 7      cost: 128        mean: 1.317e-01       std error: 9.918e-03       true error: 1.823e-02       time 35              sample sizes [256, 256, 32, 16]
# 		trial: 40     iteration: 7      cost: 128        mean: 1.499e-01       std error: 8.567e-03       true error: 2.341e-05       time 35              sample sizes [512, 128, 32, 16]
# 		trial: 45     iteration: 7      cost: 128        mean: 1.483e-01       std error: 9.682e-03       true error: 1.602e-03       time 35              sample sizes [512, 128, 32, 16]
# 	R-MLQMC DNet, 	 initial_sample_size = [8, 4, 2, 1], 	initial cost = 32.0
# 		trial: 0      iteration: 7      cost: 128        mean: 1.426e-01       std error: 2.969e-03       true error: 7.290e-03       time 36              sample sizes [256, 256, 32, 16]
# 		trial: 5      iteration: 7      cost: 128        mean: 1.479e-01       std error: 1.457e-03       true error: 2.069e-03       time 39              sample sizes [256, 256, 32, 16]
# 		trial: 10     iteration: 8      cost: 128        mean: 1.531e-01       std error: 1.690e-03       true error: 3.155e-03       time 41              sample sizes [256, 128, 64, 32]
# 		trial: 15     iteration: 7      cost: 128        mean: 1.487e-01       std error: 1.684e-03       true error: 1.189e-03       time 44              sample sizes [256, 256, 32, 16]
# 		trial: 20     iteration: 7      cost: 128        mean: 1.467e-01       std error: 2.483e-03       true error: 3.231e-03       time 47              sample sizes [256, 256, 32, 16]
# 		trial: 25     iteration: 7      cost: 128        mean: 1.481e-01       std error: 1.824e-03       true error: 1.799e-03       time 49              sample sizes [256, 256, 32, 16]
# 		trial: 30     iteration: 7      cost: 128        mean: 1.476e-01       std error: 2.145e-03       true error: 2.376e-03       time 52              sample sizes [256, 256, 32, 16]
# 		trial: 35     iteration: 7      cost: 128        mean: 1.491e-01       std error: 2.957e-03       true error: 8.261e-04       time 55              sample sizes [256, 256, 32, 16]
# 		trial: 40     iteration: 8      cost: 128        mean: 1.527e-01       std error: 2.137e-03       true error: 2.789e-03       time 58              sample sizes [256, 128, 64, 32]
# 		trial: 45     iteration: 7      cost: 128        mean: 1.498e-01       std error: 3.806e-03       true error: 1.734e-04       time 60              sample sizes [256, 256, 32, 16]
# 	IGP    DNet     Fast  DSI $\alpha=1$, 	 initial_sample_size = [64, 32, 16, 8], 	initial cost = 32.0
# 		trial: 0      iteration: 7      cost: 128        mean: 1.481e-01       std error: 2.866e-03       true error: 1.868e-03       time 67              sample sizes [128, 256, 64, 16]
# 		trial: 5      iteration: 7      cost: 128        mean: 1.486e-01       std error: 2.564e-03       true error: 1.354e-03       time 72              sample sizes [512, 128, 32, 16]
# 		trial: 10     iteration: 7      cost: 128        mean: 1.501e-01       std error: 1.340e-03       true error: 1.969e-04       time 76              sample sizes [256, 256, 32, 16]
# 		trial: 15     iteration: 7      cost: 128        mean: 1.505e-01       std error: 1.285e-03       true error: 5.184e-04       time 81              sample sizes [512, 128, 32, 16]
# 		trial: 20     iteration: 7      cost: 128        mean: 1.496e-01       std error: 9.598e-04       true error: 3.422e-04       time 85              sample sizes [256, 256, 32, 16]
# 		trial: 25     iteration: 7      cost: 128        mean: 1.502e-01       std error: 1.147e-03       true error: 2.946e-04       time 90              sample sizes [512, 128, 32, 16]
# 		trial: 30     iteration: 8      cost: 128        mean: 1.508e-01       std error: 1.299e-03       true error: 8.685e-04       time 94              sample sizes [256, 128, 64, 32]
# 		trial: 35     iteration: 7      cost: 128        mean: 1.499e-01       std error: 1.078e-03       true error: 8.581e-05       time 99              sample sizes [256, 256, 32, 16]
# 		trial: 40     iteration: 7      cost: 128        mean: 1.517e-01       std error: 1.231e-03       true error: 1.738e-03       time 103             sample sizes [256, 256, 32, 16]
# 		trial: 45     iteration: 8      cost: 128        mean: 1.501e-01       std error: 1.302e-03       true error: 1.207e-04       time 108             sample sizes [256, 128, 64, 32]
# 	IGP    DNet     Fast  DSI $\alpha=2$, 	 initial_sample_size = [64, 32, 16, 8], 	initial cost = 32.0
# 		trial: 0      iteration: 7      cost: 128        mean: 1.523e-01       std error: 2.042e-03       true error: 2.322e-03       time 112             sample sizes [512, 128, 32, 16]
# 		trial: 5      iteration: 7      cost: 128        mean: 1.510e-01       std error: 1.417e-03       true error: 1.055e-03       time 117             sample sizes [512, 128, 32, 16]
# 		trial: 10     iteration: 7      cost: 128        mean: 1.530e-01       std error: 2.401e-03       true error: 3.094e-03       time 121             sample sizes [512, 128, 32, 16]
# 		trial: 15     iteration: 7      cost: 128        mean: 1.496e-01       std error: 1.634e-03       true error: 3.817e-04       time 126             sample sizes [256, 256, 32, 16]
# 		trial: 20     iteration: 7      cost: 128        mean: 1.515e-01       std error: 1.574e-03       true error: 1.519e-03       time 130             sample sizes [512, 128, 32, 16]
# 		trial: 25     iteration: 7      cost: 128        mean: 1.500e-01       std error: 1.380e-03       true error: 9.354e-05       time 135             sample sizes [512, 128, 32, 16]
# 		trial: 30     iteration: 7      cost: 128        mean: 1.491e-01       std error: 1.812e-03       true error: 8.547e-04       time 139             sample sizes [256, 256, 32, 16]
# 		trial: 35     iteration: 7      cost: 128        mean: 1.473e-01       std error: 1.431e-03       true error: 2.666e-03       time 144             sample sizes [256, 256, 32, 16]
# 		trial: 40     iteration: 7      cost: 128        mean: 1.512e-01       std error: 1.448e-03       true error: 1.227e-03       time 148             sample sizes [512, 128, 32, 16]
# 		trial: 45     iteration: 7      cost: 128        mean: 1.500e-01       std error: 1.308e-03       true error: 1.011e-04       time 153             sample sizes [256, 256, 32, 16]
# 	IGP    DNet     Fast  DSI $\alpha=3$, 	 initial_sample_size = [64, 32, 16, 8], 	initial cost = 32.0
# 		trial: 0      iteration: 7      cost: 128        mean: 1.485e-01       std error: 1.846e-03       true error: 1.428e-03       time 157             sample sizes [512, 128, 32, 16]
# 		trial: 5      iteration: 7      cost: 128        mean: 1.511e-01       std error: 1.235e-03       true error: 1.204e-03       time 162             sample sizes [256, 256, 32, 16]
# 		trial: 10     iteration: 7      cost: 128        mean: 1.491e-01       std error: 1.274e-03       true error: 8.551e-04       time 167             sample sizes [256, 256, 32, 16]
# 		trial: 15     iteration: 7      cost: 128        mean: 1.523e-01       std error: 2.538e-03       true error: 2.399e-03       time 171             sample sizes [512, 128, 32, 16]
# 		trial: 20     iteration: 7      cost: 128        mean: 1.497e-01       std error: 1.380e-03       true error: 2.830e-04       time 176             sample sizes [256, 256, 32, 16]
# 		trial: 25     iteration: 7      cost: 128        mean: 1.492e-01       std error: 1.554e-03       true error: 6.888e-04       time 180             sample sizes [512, 128, 32, 16]
# 		trial: 30     iteration: 7      cost: 128        mean: 1.474e-01       std error: 1.959e-03       true error: 2.575e-03       time 185             sample sizes [256, 256, 32, 16]
# 		trial: 35     iteration: 7      cost: 128        mean: 1.507e-01       std error: 1.621e-03       true error: 7.164e-04       time 190             sample sizes [512, 128, 32, 16]
# 		trial: 40     iteration: 7      cost: 128        mean: 1.520e-01       std error: 2.434e-03       true error: 2.018e-03       time 195             sample sizes [512, 128, 32, 16]
# 		trial: 45     iteration: 7      cost: 128        mean: 1.521e-01       std error: 1.579e-03       true error: 2.148e-03       time 199             sample sizes [256, 256, 32, 16]
# 	IGP    DNet     Fast  DSI $\alpha=4$, 	 initial_sample_size = [64, 32, 16, 8], 	initial cost = 32.0
# 		trial: 0      iteration: 7      cost: 128        mean: 1.486e-01       std error: 2.321e-03       true error: 1.332e-03       time 204             sample sizes [512, 128, 32, 16]
# 		trial: 5      iteration: 7      cost: 128        mean: 1.498e-01       std error: 1.243e-03       true error: 1.153e-04       time 209             sample sizes [512, 128, 32, 16]
# 		trial: 10     iteration: 7      cost: 128        mean: 1.455e-01       std error: 4.856e-03       true error: 4.455e-03       time 213             sample sizes [512, 128, 32, 16]
# 		trial: 15     iteration: 7      cost: 128        mean: 1.541e-01       std error: 2.139e-03       true error: 4.208e-03       time 218             sample sizes [256, 256, 32, 16]
# 		trial: 20     iteration: 7      cost: 128        mean: 1.531e-01       std error: 2.642e-03       true error: 3.155e-03       time 223             sample sizes [512, 128, 32, 16]
# 		trial: 25     iteration: 7      cost: 128        mean: 1.527e-01       std error: 1.533e-03       true error: 2.739e-03       time 228             sample sizes [512, 128, 32, 16]
# 		trial: 30     iteration: 7      cost: 128        mean: 1.488e-01       std error: 1.618e-03       true error: 1.100e-03       time 232             sample sizes [256, 256, 32, 16]
# 		trial: 35     iteration: 8      cost: 128        mean: 1.504e-01       std error: 1.417e-03       true error: 5.102e-04       time 237             sample sizes [256, 128, 64, 32]
# 		trial: 40     iteration: 7      cost: 128        mean: 1.490e-01       std error: 2.525e-03       true error: 9.058e-04       time 242             sample sizes [512, 128, 32, 16]
# 		trial: 45     iteration: 7      cost: 128        mean: 1.481e-01       std error: 3.202e-03       true error: 1.795e-03       time 246             sample sizes [512, 128, 32, 16]
# 	MTGP   DNet     Fast  DSI $\alpha=1$ Greedy, 	 initial_sample_size = [64, 32, 16, 8], 	initial cost = 32.0
# 		trial: 0      iteration: 5      cost: 128        mean: 1.496e-01       std error: 1.390e-03       true error: 3.021e-04       time 252             sample sizes [128, 128, 32, 64]
# 		trial: 5      iteration: 7      cost: 128        mean: 1.493e-01       std error: 1.193e-03       true error: 6.143e-04       time 261             sample sizes [256, 64, 32, 64]
# 		trial: 10     iteration: 7      cost: 128        mean: 1.360e-01       std error: 5.398e-04       true error: 1.390e-02       time 272             sample sizes [128, 256, 64, 16]
# 		trial: 15     iteration: 6      cost: 128        mean: 1.520e-01       std error: 1.825e-03       true error: 2.059e-03       time 281             sample sizes [128, 128, 32, 64]
# 		trial: 20     iteration: 7      cost: 128        mean: 1.465e-01       std error: 8.454e-04       true error: 3.487e-03       time 290             sample sizes [128, 64, 128, 32]
# 		trial: 25     iteration: 7      cost: 128        mean: 1.462e-01       std error: 4.379e-04       true error: 3.765e-03       time 301             sample sizes [128, 256, 32, 32]
# 		trial: 30     iteration: 7      cost: 128        mean: 1.299e-01       std error: 1.046e-03       true error: 2.004e-02       time 311             sample sizes [128, 256, 32, 32]
# 		trial: 35     iteration: 5      cost: 128        mean: 1.479e-01       std error: 1.487e-03       true error: 2.007e-03       time 321             sample sizes [128, 128, 32, 64]
# 		trial: 40     iteration: 7      cost: 128        mean: 1.543e-01       std error: 3.379e-03       true error: 4.348e-03       time 331             sample sizes [128, 64, 128, 32]
# 		trial: 45     iteration: 7      cost: 128        mean: 1.455e-01       std error: 9.188e-04       true error: 4.412e-03       time 342             sample sizes [128, 256, 32, 32]
# 	MTGP   DNet     Fast  DSI $\alpha=2$ Greedy, 	 initial_sample_size = [64, 32, 16, 8], 	initial cost = 32.0
# 		trial: 0      iteration: 5      cost: 128        mean: 1.489e-01       std error: 2.404e-03       true error: 9.946e-04       time 350             sample sizes [256, 128, 64, 32]
# 		trial: 5      iteration: 5      cost: 128        mean: 1.453e-01       std error: 3.574e-03       true error: 4.682e-03       time 359             sample sizes [256, 64, 128, 16]
# 		trial: 10     iteration: 6      cost: 128        mean: 1.374e-01       std error: 2.958e-03       true error: 1.258e-02       time 368             sample sizes [128, 64, 64, 64]
# 		trial: 15     iteration: 5      cost: 128        mean: 1.531e-01       std error: 3.423e-03       true error: 3.207e-03       time 377             sample sizes [512, 64, 64, 16]
# 		trial: 20     iteration: 5      cost: 128        mean: 1.385e-01       std error: 2.821e-03       true error: 1.147e-02       time 386             sample sizes [256, 128, 64, 32]
# 		trial: 25     iteration: 5      cost: 128        mean: 1.488e-01       std error: 4.643e-03       true error: 1.118e-03       time 396             sample sizes [256, 256, 32, 16]
# 		trial: 30     iteration: 7      cost: 128        mean: 1.353e-01       std error: 2.703e-03       true error: 1.465e-02       time 405             sample sizes [512, 64, 32, 32]
# 		trial: 35     iteration: 6      cost: 128        mean: 1.449e-01       std error: 3.334e-03       true error: 5.067e-03       time 414             sample sizes [256, 128, 64, 32]
# 		trial: 40     iteration: 5      cost: 128        mean: 1.433e-01       std error: 3.450e-03       true error: 6.594e-03       time 424             sample sizes [256, 64, 32, 64]
# 		trial: 45     iteration: 5      cost: 128        mean: 1.493e-01       std error: 2.446e-03       true error: 6.671e-04       time 433             sample sizes [256, 128, 64, 32]
# 	MTGP   DNet     Fast  DSI $\alpha=3$ Greedy, 	 initial_sample_size = [64, 32, 16, 8], 	initial cost = 32.0
# 		trial: 0      iteration: 7      cost: 128        mean: 1.449e-01       std error: 4.418e-03       true error: 5.013e-03       time 442             sample sizes [128, 256, 64, 16]
# 		trial: 5      iteration: 5      cost: 128        mean: 1.514e-01       std error: 1.050e-02       true error: 1.502e-03       time 451             sample sizes [256, 64, 32, 64]
# 		trial: 10     iteration: 5      cost: 128        mean: 1.417e-01       std error: 5.701e-03       true error: 8.252e-03       time 461             sample sizes [256, 64, 32, 64]
# 		trial: 15     iteration: 7      cost: 128        mean: 1.404e-01       std error: 5.759e-03       true error: 9.584e-03       time 470             sample sizes [256, 64, 32, 64]
# 		trial: 20     iteration: 5      cost: 128        mean: 1.404e-01       std error: 2.480e-03       true error: 9.542e-03       time 480             sample sizes [128, 128, 32, 64]
# 		trial: 25     iteration: 5      cost: 128        mean: 1.264e-01       std error: 3.115e-03       true error: 2.352e-02       time 489             sample sizes [128, 256, 64, 16]
# 		trial: 30     iteration: 5      cost: 128        mean: 1.232e-01       std error: 2.534e-03       true error: 2.673e-02       time 499             sample sizes [128, 64, 64, 64]
# 		trial: 35     iteration: 5      cost: 128        mean: 1.270e-01       std error: 3.925e-03       true error: 2.294e-02       time 510             sample sizes [256, 256, 32, 16]
# 		trial: 40     iteration: 6      cost: 128        mean: 1.475e-01       std error: 3.642e-03       true error: 2.485e-03       time 520             sample sizes [256, 128, 64, 32]
# 		trial: 45     iteration: 6      cost: 128        mean: 1.341e-01       std error: 3.365e-03       true error: 1.581e-02       time 529             sample sizes [128, 256, 32, 32]
# 	MTGP   DNet     Fast  DSI $\alpha=4$ Greedy, 	 initial_sample_size = [64, 32, 16, 8], 	initial cost = 32.0
# 		trial: 0      iteration: 6      cost: 128        mean: 1.221e-01       std error: 3.098e-03       true error: 2.787e-02       time 538             sample sizes [128, 256, 64, 16]
# 		trial: 5      iteration: 5      cost: 128        mean: 1.493e-01       std error: 4.576e-03       true error: 6.133e-04       time 549             sample sizes [256, 256, 32, 16]
# 		trial: 10     iteration: 5      cost: 128        mean: 1.534e-01       std error: 2.473e-03       true error: 3.487e-03       time 557             sample sizes [256, 256, 32, 16]
# 		trial: 15     iteration: 6      cost: 128        mean: 1.522e-01       std error: 3.932e-03       true error: 2.214e-03       time 567             sample sizes [128, 64, 64, 64]
# 		trial: 20     iteration: 6      cost: 128        mean: 1.407e-01       std error: 2.813e-03       true error: 9.198e-03       time 577             sample sizes [128, 64, 128, 32]
# 		trial: 25     iteration: 6      cost: 128        mean: 1.395e-01       std error: 2.353e-03       true error: 1.039e-02       time 586             sample sizes [128, 64, 128, 32]
# 		trial: 30     iteration: 6      cost: 128        mean: 1.599e-01       std error: 4.907e-03       true error: 9.918e-03       time 596             sample sizes [256, 64, 32, 64]
# 		trial: 35     iteration: 5      cost: 128        mean: 1.498e-01       std error: 3.023e-03       true error: 1.781e-04       time 606             sample sizes [256, 64, 32, 64]
# 		trial: 40     iteration: 7      cost: 128        mean: 1.438e-01       std error: 4.075e-03       true error: 6.126e-03       time 616             sample sizes [128, 256, 64, 16]
# 		trial: 45     iteration: 5      cost: 128        mean: 1.443e-01       std error: 6.985e-03       true error: 5.621e-03       time 624             sample sizes [128, 128, 32, 64]
#
# budget = 256, initial budget = 64
# 	MLMC    IID, 	 initial_sample_size = [128, 64, 32, 16], 	initial cost = 64.0
# 		trial: 0      iteration: 7      cost: 256        mean: 1.516e-01       std error: 5.664e-03       true error: 1.651e-03       time 633             sample sizes [1024, 256, 64, 32]
# 		trial: 5      iteration: 7      cost: 256        mean: 1.523e-01       std error: 6.474e-03       true error: 2.392e-03       time 634             sample sizes [1024, 256, 64, 32]
# 		trial: 10     iteration: 7      cost: 256        mean: 1.578e-01       std error: 6.274e-03       true error: 7.883e-03       time 634             sample sizes [1024, 256, 64, 32]
# 		trial: 15     iteration: 7      cost: 256        mean: 1.431e-01       std error: 5.690e-03       true error: 6.808e-03       time 634             sample sizes [1024, 256, 64, 32]
# 		trial: 20     iteration: 7      cost: 256        mean: 1.374e-01       std error: 5.986e-03       true error: 1.258e-02       time 635             sample sizes [512, 512, 64, 32]
# 		trial: 25     iteration: 7      cost: 256        mean: 1.468e-01       std error: 6.317e-03       true error: 3.110e-03       time 635             sample sizes [1024, 256, 64, 32]
# 		trial: 30     iteration: 7      cost: 256        mean: 1.541e-01       std error: 6.158e-03       true error: 4.125e-03       time 636             sample sizes [1024, 256, 64, 32]
# 		trial: 35     iteration: 7      cost: 256        mean: 1.469e-01       std error: 6.663e-03       true error: 3.005e-03       time 636             sample sizes [1024, 256, 64, 32]
# 		trial: 40     iteration: 7      cost: 256        mean: 1.465e-01       std error: 6.155e-03       true error: 3.399e-03       time 637             sample sizes [1024, 256, 64, 32]
# 		trial: 45     iteration: 7      cost: 256        mean: 1.539e-01       std error: 6.709e-03       true error: 3.952e-03       time 637             sample sizes [1024, 256, 64, 32]
# 	R-MLQMC DNet, 	 initial_sample_size = [16, 8, 4, 2], 	initial cost = 64.0
# 		trial: 0      iteration: 7      cost: 256        mean: 1.474e-01       std error: 2.881e-03       true error: 2.490e-03       time 639             sample sizes [1024, 256, 64, 32]
# 		trial: 5      iteration: 7      cost: 256        mean: 1.456e-01       std error: 1.889e-03       true error: 4.305e-03       time 642             sample sizes [256, 512, 128, 32]
# 		trial: 10     iteration: 7      cost: 256        mean: 1.462e-01       std error: 2.457e-03       true error: 3.704e-03       time 646             sample sizes [512, 512, 64, 32]
# 		trial: 15     iteration: 7      cost: 256        mean: 1.461e-01       std error: 1.944e-03       true error: 3.834e-03       time 650             sample sizes [512, 512, 64, 32]
# 		trial: 20     iteration: 8      cost: 256        mean: 1.511e-01       std error: 1.608e-03       true error: 1.171e-03       time 654             sample sizes [512, 256, 128, 64]
# 		trial: 25     iteration: 7      cost: 256        mean: 1.498e-01       std error: 3.810e-03       true error: 1.120e-04       time 658             sample sizes [512, 512, 64, 32]
# 		trial: 30     iteration: 7      cost: 256        mean: 1.526e-01       std error: 1.935e-03       true error: 2.679e-03       time 662             sample sizes [512, 512, 64, 32]
# 		trial: 35     iteration: 7      cost: 256        mean: 1.445e-01       std error: 1.449e-03       true error: 5.453e-03       time 666             sample sizes [256, 512, 128, 32]
# 		trial: 40     iteration: 7      cost: 256        mean: 1.482e-01       std error: 1.948e-03       true error: 1.756e-03       time 669             sample sizes [512, 512, 64, 32]
# 		trial: 45     iteration: 7      cost: 256        mean: 1.494e-01       std error: 1.480e-03       true error: 5.214e-04       time 673             sample sizes [512, 512, 64, 32]
# 	IGP    DNet     Fast  DSI $\alpha=1$, 	 initial_sample_size = [128, 64, 32, 16], 	initial cost = 64.0
# 		trial: 0      iteration: 7      cost: 256        mean: 1.501e-01       std error: 8.888e-04       true error: 1.824e-04       time 677             sample sizes [1024, 256, 64, 32]
# 		trial: 5      iteration: 7      cost: 256        mean: 1.500e-01       std error: 7.846e-04       true error: 2.348e-05       time 683             sample sizes [1024, 256, 64, 32]
# 		trial: 10     iteration: 8      cost: 256        mean: 1.499e-01       std error: 7.869e-04       true error: 2.499e-06       time 688             sample sizes [512, 256, 128, 64]
# 		trial: 15     iteration: 7      cost: 256        mean: 1.501e-01       std error: 8.573e-04       true error: 2.100e-04       time 694             sample sizes [512, 512, 64, 32]
# 		trial: 20     iteration: 7      cost: 256        mean: 1.513e-01       std error: 9.026e-04       true error: 1.385e-03       time 699             sample sizes [512, 512, 64, 32]
# 		trial: 25     iteration: 8      cost: 256        mean: 1.499e-01       std error: 1.004e-03       true error: 1.389e-05       time 705             sample sizes [512, 256, 128, 64]
# 		trial: 30     iteration: 7      cost: 256        mean: 1.501e-01       std error: 7.651e-04       true error: 1.458e-04       time 710             sample sizes [512, 512, 64, 32]
# 		trial: 35     iteration: 8      cost: 256        mean: 1.503e-01       std error: 8.145e-04       true error: 3.838e-04       time 716             sample sizes [512, 256, 128, 64]
# 		trial: 40     iteration: 7      cost: 256        mean: 1.483e-01       std error: 7.564e-04       true error: 1.641e-03       time 721             sample sizes [512, 512, 64, 32]
# 		trial: 45     iteration: 8      cost: 256        mean: 1.515e-01       std error: 8.812e-04       true error: 1.526e-03       time 727             sample sizes [512, 256, 128, 64]
# 	IGP    DNet     Fast  DSI $\alpha=2$, 	 initial_sample_size = [128, 64, 32, 16], 	initial cost = 64.0
# 		trial: 0      iteration: 7      cost: 256        mean: 1.487e-01       std error: 1.302e-03       true error: 1.190e-03       time 733             sample sizes [1024, 256, 64, 32]
# 		trial: 5      iteration: 8      cost: 256        mean: 1.507e-01       std error: 1.186e-03       true error: 7.655e-04       time 738             sample sizes [512, 256, 128, 64]
# 		trial: 10     iteration: 7      cost: 256        mean: 1.482e-01       std error: 1.049e-03       true error: 1.738e-03       time 743             sample sizes [512, 512, 64, 32]
# 		trial: 15     iteration: 7      cost: 256        mean: 1.487e-01       std error: 1.154e-03       true error: 1.227e-03       time 749             sample sizes [1024, 256, 64, 32]
# 		trial: 20     iteration: 8      cost: 256        mean: 1.495e-01       std error: 1.342e-03       true error: 4.246e-04       time 754             sample sizes [512, 256, 128, 64]
# 		trial: 25     iteration: 7      cost: 256        mean: 1.470e-01       std error: 1.364e-03       true error: 2.968e-03       time 760             sample sizes [512, 512, 64, 32]
# 		trial: 30     iteration: 7      cost: 256        mean: 1.486e-01       std error: 1.005e-03       true error: 1.358e-03       time 765             sample sizes [512, 512, 64, 32]
# 		trial: 35     iteration: 7      cost: 256        mean: 1.498e-01       std error: 8.453e-04       true error: 1.142e-04       time 771             sample sizes [512, 512, 64, 32]
# 		trial: 40     iteration: 7      cost: 256        mean: 1.503e-01       std error: 1.096e-03       true error: 3.274e-04       time 776             sample sizes [1024, 256, 64, 32]
# 		trial: 45     iteration: 7      cost: 256        mean: 1.490e-01       std error: 1.048e-03       true error: 9.785e-04       time 782             sample sizes [512, 512, 64, 32]
# 	IGP    DNet     Fast  DSI $\alpha=3$, 	 initial_sample_size = [128, 64, 32, 16], 	initial cost = 64.0
# 		trial: 0      iteration: 7      cost: 256        mean: 1.502e-01       std error: 1.340e-03       true error: 2.279e-04       time 787             sample sizes [512, 512, 64, 32]
# 		trial: 5      iteration: 7      cost: 256        mean: 1.509e-01       std error: 1.163e-03       true error: 9.378e-04       time 793             sample sizes [1024, 256, 64, 32]
# 		trial: 10     iteration: 7      cost: 256        mean: 1.508e-01       std error: 1.563e-03       true error: 8.772e-04       time 799             sample sizes [1024, 256, 64, 32]
# 		trial: 15     iteration: 7      cost: 256        mean: 1.478e-01       std error: 2.688e-03       true error: 2.104e-03       time 804             sample sizes [512, 512, 64, 32]
# 		trial: 20     iteration: 7      cost: 256        mean: 1.516e-01       std error: 1.133e-03       true error: 1.638e-03       time 810             sample sizes [1024, 256, 64, 32]
# 		trial: 25     iteration: 7      cost: 256        mean: 1.512e-01       std error: 1.085e-03       true error: 1.244e-03       time 816             sample sizes [512, 512, 64, 32]
# 		trial: 30     iteration: 8      cost: 256        mean: 1.498e-01       std error: 8.524e-04       true error: 9.156e-05       time 821             sample sizes [512, 256, 128, 64]
# 		trial: 35     iteration: 7      cost: 256        mean: 1.494e-01       std error: 9.302e-04       true error: 5.589e-04       time 827             sample sizes [512, 512, 64, 32]
# 		trial: 40     iteration: 7      cost: 256        mean: 1.507e-01       std error: 7.091e-04       true error: 7.619e-04       time 833             sample sizes [512, 512, 64, 32]
# 		trial: 45     iteration: 7      cost: 256        mean: 1.515e-01       std error: 9.017e-04       true error: 1.575e-03       time 838             sample sizes [512, 512, 64, 32]
# 	IGP    DNet     Fast  DSI $\alpha=4$, 	 initial_sample_size = [128, 64, 32, 16], 	initial cost = 64.0
# 		trial: 0      iteration: 7      cost: 256        mean: 1.503e-01       std error: 8.680e-04       true error: 3.357e-04       time 844             sample sizes [1024, 256, 64, 32]
# 		trial: 5      iteration: 7      cost: 256        mean: 1.497e-01       std error: 9.304e-04       true error: 2.819e-04       time 850             sample sizes [512, 512, 64, 32]
# 		trial: 10     iteration: 7      cost: 256        mean: 1.493e-01       std error: 9.771e-04       true error: 6.800e-04       time 856             sample sizes [512, 512, 64, 32]
# 		trial: 15     iteration: 7      cost: 256        mean: 1.512e-01       std error: 8.327e-04       true error: 1.237e-03       time 861             sample sizes [1024, 256, 64, 32]
# 		trial: 20     iteration: 7      cost: 256        mean: 1.505e-01       std error: 1.386e-03       true error: 5.302e-04       time 867             sample sizes [512, 512, 64, 32]
# 		trial: 25     iteration: 8      cost: 256        mean: 1.503e-01       std error: 8.432e-04       true error: 3.681e-04       time 873             sample sizes [512, 256, 128, 64]
# 		trial: 30     iteration: 7      cost: 256        mean: 1.496e-01       std error: 1.289e-03       true error: 3.693e-04       time 879             sample sizes [1024, 256, 64, 32]
# 		trial: 35     iteration: 7      cost: 256        mean: 1.493e-01       std error: 7.578e-04       true error: 5.960e-04       time 885             sample sizes [512, 512, 64, 32]
# 		trial: 40     iteration: 7      cost: 256        mean: 1.516e-01       std error: 8.686e-04       true error: 1.660e-03       time 891             sample sizes [1024, 256, 64, 32]
# 		trial: 45     iteration: 7      cost: 256        mean: 1.502e-01       std error: 1.807e-03       true error: 2.845e-04       time 897             sample sizes [1024, 256, 64, 32]
# 	MTGP   DNet     Fast  DSI $\alpha=1$ Greedy, 	 initial_sample_size = [128, 64, 32, 16], 	initial cost = 64.0
# 		trial: 0      iteration: 7      cost: 256        mean: 1.473e-01       std error: 8.048e-04       true error: 2.625e-03       time 904             sample sizes [256, 512, 64, 64]
# 		trial: 5      iteration: 6      cost: 256        mean: 1.471e-01       std error: 4.699e-04       true error: 2.834e-03       time 915             sample sizes [256, 128, 256, 64]
# 		trial: 10     iteration: 7      cost: 256        mean: 1.513e-01       std error: 9.073e-04       true error: 1.344e-03       time 928             sample sizes [256, 256, 64, 128]
# 		trial: 15     iteration: 7      cost: 256        mean: 1.461e-01       std error: 2.989e-04       true error: 3.817e-03       time 939             sample sizes [256, 512, 64, 64]
# 		trial: 20     iteration: 7      cost: 256        mean: 1.486e-01       std error: 4.146e-04       true error: 1.293e-03       time 950             sample sizes [256, 128, 256, 64]
# 		trial: 25     iteration: 7      cost: 256        mean: 1.403e-01       std error: 8.327e-04       true error: 9.681e-03       time 962             sample sizes [256, 128, 256, 64]
# 		trial: 30     iteration: 7      cost: 256        mean: 1.500e-01       std error: 3.253e-04       true error: 9.239e-05       time 973             sample sizes [256, 128, 256, 64]
# 		trial: 35     iteration: 7      cost: 256        mean: 1.530e-01       std error: 1.368e-03       true error: 3.104e-03       time 984             sample sizes [256, 256, 64, 128]
# 		trial: 40     iteration: 7      cost: 256        mean: 1.474e-01       std error: 6.537e-04       true error: 2.550e-03       time 995             sample sizes [512, 128, 64, 128]
# 		trial: 45     iteration: 7      cost: 256        mean: 1.490e-01       std error: 8.830e-04       true error: 8.978e-04       time 1007            sample sizes [512, 128, 64, 128]
# 	MTGP   DNet     Fast  DSI $\alpha=2$ Greedy, 	 initial_sample_size = [128, 64, 32, 16], 	initial cost = 64.0
# 		trial: 0      iteration: 6      cost: 256        mean: 1.448e-01       std error: 2.720e-03       true error: 5.145e-03       time 1018            sample sizes [512, 128, 64, 128]
# 		trial: 5      iteration: 6      cost: 256        mean: 1.457e-01       std error: 1.874e-03       true error: 4.200e-03       time 1029            sample sizes [256, 256, 64, 128]
# 		trial: 10     iteration: 5      cost: 256        mean: 1.422e-01       std error: 2.322e-03       true error: 7.780e-03       time 1041            sample sizes [512, 256, 128, 64]
# 		trial: 15     iteration: 6      cost: 256        mean: 1.489e-01       std error: 3.171e-03       true error: 1.017e-03       time 1052            sample sizes [256, 512, 64, 64]
# 		trial: 20     iteration: 5      cost: 256        mean: 1.427e-01       std error: 1.201e-03       true error: 7.258e-03       time 1065            sample sizes [256, 256, 64, 128]
# 		trial: 25     iteration: 5      cost: 256        mean: 1.457e-01       std error: 3.353e-03       true error: 4.262e-03       time 1077            sample sizes [512, 256, 128, 64]
# 		trial: 30     iteration: 6      cost: 256        mean: 1.468e-01       std error: 2.247e-03       true error: 3.104e-03       time 1087            sample sizes [512, 256, 128, 64]
# 		trial: 35     iteration: 5      cost: 256        mean: 1.435e-01       std error: 2.343e-03       true error: 6.403e-03       time 1097            sample sizes [256, 128, 128, 128]
# 		trial: 40     iteration: 5      cost: 256        mean: 1.550e-01       std error: 2.256e-03       true error: 5.076e-03       time 1109            sample sizes [512, 256, 128, 64]
# 		trial: 45     iteration: 6      cost: 256        mean: 1.447e-01       std error: 1.818e-03       true error: 5.256e-03       time 1121            sample sizes [512, 256, 128, 64]
# 	MTGP   DNet     Fast  DSI $\alpha=3$ Greedy, 	 initial_sample_size = [128, 64, 32, 16], 	initial cost = 64.0
# 		trial: 0      iteration: 6      cost: 256        mean: 1.387e-01       std error: 1.527e-03       true error: 1.126e-02       time 1133            sample sizes [512, 256, 128, 64]
# 		trial: 5      iteration: 5      cost: 256        mean: 1.520e-01       std error: 1.917e-03       true error: 2.049e-03       time 1144            sample sizes [512, 256, 128, 64]
# 		trial: 10     iteration: 6      cost: 256        mean: 1.460e-01       std error: 2.114e-03       true error: 3.961e-03       time 1156            sample sizes [256, 512, 64, 64]
# 		trial: 15     iteration: 6      cost: 256        mean: 1.567e-01       std error: 6.890e-03       true error: 6.792e-03       time 1168            sample sizes [512, 256, 128, 64]
# 		trial: 20     iteration: 6      cost: 256        mean: 1.384e-01       std error: 3.225e-03       true error: 1.150e-02       time 1180            sample sizes [512, 256, 128, 64]
# 		trial: 25     iteration: 6      cost: 256        mean: 1.458e-01       std error: 4.307e-03       true error: 4.176e-03       time 1190            sample sizes [512, 256, 128, 64]
# 		trial: 30     iteration: 6      cost: 256        mean: 1.349e-01       std error: 2.224e-03       true error: 1.508e-02       time 1202            sample sizes [512, 256, 128, 64]
# 		trial: 35     iteration: 6      cost: 256        mean: 1.501e-01       std error: 4.042e-03       true error: 1.968e-04       time 1216            sample sizes [512, 128, 256, 32]
# 		trial: 40     iteration: 5      cost: 256        mean: 1.461e-01       std error: 3.468e-03       true error: 3.789e-03       time 1228            sample sizes [256, 128, 256, 64]
# 		trial: 45     iteration: 7      cost: 256        mean: 1.460e-01       std error: 5.232e-03       true error: 3.910e-03       time 1240            sample sizes [256, 512, 64, 64]
# 	MTGP   DNet     Fast  DSI $\alpha=4$ Greedy, 	 initial_sample_size = [128, 64, 32, 16], 	initial cost = 64.0
# 		trial: 0      iteration: 5      cost: 256        mean: 1.392e-01       std error: 2.328e-03       true error: 1.078e-02       time 1252            sample sizes [256, 512, 128, 32]
# 		trial: 5      iteration: 5      cost: 256        mean: 1.367e-01       std error: 1.738e-03       true error: 1.319e-02       time 1265            sample sizes [256, 128, 128, 128]
# 		trial: 10     iteration: 6      cost: 256        mean: 1.261e-01       std error: 2.272e-03       true error: 2.387e-02       time 1277            sample sizes [256, 128, 256, 64]
# 		trial: 15     iteration: 6      cost: 256        mean: 1.711e-01       std error: 9.533e-03       true error: 2.115e-02       time 1288            sample sizes [256, 128, 128, 128]
# 		trial: 20     iteration: 6      cost: 256        mean: 1.495e-01       std error: 5.885e-03       true error: 4.767e-04       time 1299            sample sizes [256, 512, 64, 64]
# 		trial: 25     iteration: 7      cost: 256        mean: 1.547e-01       std error: 3.152e-03       true error: 4.804e-03       time 1312            sample sizes [256, 512, 64, 64]
# 		trial: 30     iteration: 6      cost: 256        mean: 1.208e-01       std error: 4.509e-03       true error: 2.914e-02       time 1324            sample sizes [512, 128, 256, 32]
# 		trial: 35     iteration: 6      cost: 256        mean: 1.433e-01       std error: 1.830e-03       true error: 6.667e-03       time 1336            sample sizes [512, 256, 128, 64]
# 		trial: 40     iteration: 5      cost: 256        mean: 1.463e-01       std error: 3.242e-03       true error: 3.659e-03       time 1347            sample sizes [256, 256, 256, 32]
# 		trial: 45     iteration: 7      cost: 256        mean: 1.412e-01       std error: 5.557e-03       true error: 8.710e-03       time 1360            sample sizes [256, 512, 64, 64]
#
# budget = 512, initial budget = 128
# 	MLMC    IID, 	 initial_sample_size = [256, 128, 64, 32], 	initial cost = 128.0
# 		trial: 0      iteration: 7      cost: 512        mean: 1.480e-01       std error: 4.290e-03       true error: 1.952e-03       time 1368            sample sizes [2048, 512, 128, 64]
# 		trial: 5      iteration: 7      cost: 512        mean: 1.523e-01       std error: 4.892e-03       true error: 2.323e-03       time 1369            sample sizes [2048, 512, 128, 64]
# 		trial: 10     iteration: 7      cost: 512        mean: 1.546e-01       std error: 4.191e-03       true error: 4.688e-03       time 1370            sample sizes [2048, 512, 128, 64]
# 		trial: 15     iteration: 7      cost: 512        mean: 1.543e-01       std error: 4.685e-03       true error: 4.379e-03       time 1371            sample sizes [2048, 512, 128, 64]
# 		trial: 20     iteration: 7      cost: 512        mean: 1.547e-01       std error: 4.252e-03       true error: 4.720e-03       time 1372            sample sizes [2048, 512, 128, 64]
# 		trial: 25     iteration: 7      cost: 512        mean: 1.539e-01       std error: 3.854e-03       true error: 3.981e-03       time 1373            sample sizes [2048, 512, 128, 64]
# 		trial: 30     iteration: 7      cost: 512        mean: 1.478e-01       std error: 3.973e-03       true error: 2.157e-03       time 1374            sample sizes [2048, 512, 128, 64]
# 		trial: 35     iteration: 7      cost: 512        mean: 1.461e-01       std error: 4.948e-03       true error: 3.878e-03       time 1375            sample sizes [2048, 512, 128, 64]
# 		trial: 40     iteration: 7      cost: 512        mean: 1.478e-01       std error: 4.247e-03       true error: 2.145e-03       time 1376            sample sizes [2048, 512, 128, 64]
# 		trial: 45     iteration: 7      cost: 512        mean: 1.514e-01       std error: 3.912e-03       true error: 1.421e-03       time 1377            sample sizes [2048, 512, 128, 64]
# 	R-MLQMC DNet, 	 initial_sample_size = [32, 16, 8, 4], 	initial cost = 128.0
# 		trial: 0      iteration: 7      cost: 512        mean: 1.527e-01       std error: 9.061e-04       true error: 2.795e-03       time 1379            sample sizes [1024, 1024, 128, 64]
# 		trial: 5      iteration: 8      cost: 512        mean: 1.484e-01       std error: 6.787e-04       true error: 1.560e-03       time 1384            sample sizes [1024, 512, 256, 128]
# 		trial: 10     iteration: 7      cost: 512        mean: 1.502e-01       std error: 1.162e-03       true error: 3.090e-04       time 1388            sample sizes [2048, 512, 128, 64]
# 		trial: 15     iteration: 7      cost: 512        mean: 1.482e-01       std error: 8.364e-04       true error: 1.770e-03       time 1393            sample sizes [2048, 512, 128, 64]
# 		trial: 20     iteration: 8      cost: 512        mean: 1.510e-01       std error: 8.361e-04       true error: 1.084e-03       time 1398            sample sizes [1024, 512, 256, 128]
# 		trial: 25     iteration: 7      cost: 512        mean: 1.491e-01       std error: 8.389e-04       true error: 8.406e-04       time 1403            sample sizes [1024, 1024, 128, 64]
# 		trial: 30     iteration: 7      cost: 512        mean: 1.496e-01       std error: 8.525e-04       true error: 3.794e-04       time 1408            sample sizes [1024, 1024, 128, 64]
# 		trial: 35     iteration: 8      cost: 512        mean: 1.495e-01       std error: 1.054e-03       true error: 4.875e-04       time 1412            sample sizes [1024, 512, 256, 128]
# 		trial: 40     iteration: 7      cost: 512        mean: 1.509e-01       std error: 1.065e-03       true error: 9.627e-04       time 1417            sample sizes [2048, 512, 128, 64]
# 		trial: 45     iteration: 7      cost: 512        mean: 1.497e-01       std error: 1.138e-03       true error: 2.814e-04       time 1422            sample sizes [1024, 1024, 128, 64]
# 	IGP    DNet     Fast  DSI $\alpha=1$, 	 initial_sample_size = [256, 128, 64, 32], 	initial cost = 128.0
# 		trial: 0      iteration: 7      cost: 512        mean: 1.494e-01       std error: 4.264e-04       true error: 4.887e-04       time 1427            sample sizes [1024, 1024, 128, 64]
# 		trial: 5      iteration: 7      cost: 512        mean: 1.497e-01       std error: 3.724e-04       true error: 1.973e-04       time 1434            sample sizes [1024, 1024, 128, 64]
# 		trial: 10     iteration: 8      cost: 512        mean: 1.504e-01       std error: 4.065e-04       true error: 4.241e-04       time 1440            sample sizes [1024, 512, 256, 128]
# 		trial: 15     iteration: 8      cost: 512        mean: 1.493e-01       std error: 4.027e-04       true error: 5.970e-04       time 1447            sample sizes [1024, 512, 256, 128]
# 		trial: 20     iteration: 8      cost: 512        mean: 1.498e-01       std error: 5.118e-04       true error: 9.879e-05       time 1454            sample sizes [1024, 512, 256, 128]
# 		trial: 25     iteration: 8      cost: 512        mean: 1.494e-01       std error: 5.698e-04       true error: 5.144e-04       time 1461            sample sizes [1024, 512, 256, 128]
# 		trial: 30     iteration: 7      cost: 512        mean: 1.494e-01       std error: 4.847e-04       true error: 4.935e-04       time 1467            sample sizes [1024, 1024, 128, 64]
# 		trial: 35     iteration: 8      cost: 512        mean: 1.501e-01       std error: 7.621e-04       true error: 1.181e-04       time 1474            sample sizes [1024, 512, 256, 128]
# 		trial: 40     iteration: 8      cost: 512        mean: 1.496e-01       std error: 4.734e-04       true error: 3.117e-04       time 1481            sample sizes [1024, 512, 256, 128]
# 		trial: 45     iteration: 8      cost: 512        mean: 1.502e-01       std error: 4.676e-04       true error: 2.568e-04       time 1488            sample sizes [1024, 512, 256, 128]
# 	IGP    DNet     Fast  DSI $\alpha=2$, 	 initial_sample_size = [256, 128, 64, 32], 	initial cost = 128.0
# 		trial: 0      iteration: 7      cost: 512        mean: 1.503e-01       std error: 6.777e-04       true error: 3.856e-04       time 1495            sample sizes [1024, 1024, 128, 64]
# 		trial: 5      iteration: 8      cost: 512        mean: 1.504e-01       std error: 6.382e-04       true error: 4.851e-04       time 1502            sample sizes [1024, 512, 256, 128]
# 		trial: 10     iteration: 8      cost: 512        mean: 1.500e-01       std error: 5.572e-04       true error: 2.139e-05       time 1508            sample sizes [1024, 512, 256, 128]
# 		trial: 15     iteration: 7      cost: 512        mean: 1.506e-01       std error: 5.806e-04       true error: 6.792e-04       time 1515            sample sizes [2048, 512, 128, 64]
# 		trial: 20     iteration: 7      cost: 512        mean: 1.499e-01       std error: 5.123e-04       true error: 6.358e-06       time 1522            sample sizes [1024, 1024, 128, 64]
# 		trial: 25     iteration: 8      cost: 512        mean: 1.499e-01       std error: 6.393e-04       true error: 8.276e-05       time 1528            sample sizes [1024, 512, 256, 128]
# 		trial: 30     iteration: 7      cost: 512        mean: 1.495e-01       std error: 5.773e-04       true error: 4.162e-04       time 1535            sample sizes [1024, 1024, 128, 64]
# 		trial: 35     iteration: 7      cost: 512        mean: 1.498e-01       std error: 4.343e-04       true error: 1.133e-04       time 1542            sample sizes [1024, 1024, 128, 64]
# 		trial: 40     iteration: 8      cost: 512        mean: 1.504e-01       std error: 6.022e-04       true error: 4.810e-04       time 1548            sample sizes [1024, 512, 256, 128]
# 		trial: 45     iteration: 8      cost: 512        mean: 1.503e-01       std error: 7.305e-04       true error: 3.857e-04       time 1555            sample sizes [1024, 512, 256, 128]
# 	IGP    DNet     Fast  DSI $\alpha=3$, 	 initial_sample_size = [256, 128, 64, 32], 	initial cost = 128.0
# 		trial: 0      iteration: 7      cost: 512        mean: 1.499e-01       std error: 5.804e-04       true error: 4.421e-05       time 1562            sample sizes [2048, 512, 128, 64]
# 		trial: 5      iteration: 7      cost: 512        mean: 1.499e-01       std error: 7.055e-04       true error: 7.502e-05       time 1569            sample sizes [1024, 1024, 128, 64]
# 		trial: 10     iteration: 7      cost: 512        mean: 1.500e-01       std error: 5.276e-04       true error: 8.106e-05       time 1576            sample sizes [1024, 1024, 128, 64]
# 		trial: 15     iteration: 7      cost: 512        mean: 1.498e-01       std error: 8.040e-04       true error: 1.287e-04       time 1583            sample sizes [1024, 1024, 128, 64]
# 		trial: 20     iteration: 8      cost: 512        mean: 1.497e-01       std error: 5.627e-04       true error: 2.365e-04       time 1590            sample sizes [1024, 512, 256, 128]
# 		trial: 25     iteration: 7      cost: 512        mean: 1.508e-01       std error: 6.361e-04       true error: 9.115e-04       time 1597            sample sizes [1024, 1024, 128, 64]
# 		trial: 30     iteration: 8      cost: 512        mean: 1.494e-01       std error: 4.905e-04       true error: 5.752e-04       time 1604            sample sizes [1024, 512, 256, 128]
# 		trial: 35     iteration: 7      cost: 512        mean: 1.504e-01       std error: 5.062e-04       true error: 4.225e-04       time 1612            sample sizes [1024, 1024, 128, 64]
# 		trial: 40     iteration: 7      cost: 512        mean: 1.503e-01       std error: 4.769e-04       true error: 3.424e-04       time 1619            sample sizes [1024, 1024, 128, 64]
# ...
# 		trial: 45     iteration: 8      cost: 2048       mean: 1.502e-01       std error: 2.821e-04       true error: 3.032e-04       time 3659            sample sizes [4096, 2048, 1024, 512]
# 	IGP    DNet     Fast  DSI $\alpha=1$, 	 initial_sample_size = [1024, 512, 256, 128], 	initial cost = 512.0
# 		trial: 0      iteration: 7      cost: 2048       mean: 1.500e-01       std error: 1.705e-04       true error: 5.589e-05       time 3669            sample sizes [8192, 2048, 512, 256]
# 		trial: 5      iteration: 7      cost: 2048       mean: 1.498e-01       std error: 1.705e-04       true error: 1.633e-04       time 3683            sample sizes [4096, 4096, 512, 256]
# 		trial: 10     iteration: 7      cost: 2048       mean: 1.496e-01       std error: 1.949e-04       true error: 3.146e-04       time 3695            sample sizes [2048, 4096, 1024, 256]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.499e-01       std error: 1.643e-04       true error: 6.922e-05       time 3708            sample sizes [4096, 2048, 1024, 512]
# 		trial: 20     iteration: 7      cost: 2048       mean: 1.499e-01       std error: 1.575e-04       true error: 4.780e-05       time 3720            sample sizes [4096, 4096, 512, 256]
# 		trial: 25     iteration: 8      cost: 2048       mean: 1.502e-01       std error: 1.997e-04       true error: 2.707e-04       time 3733            sample sizes [4096, 2048, 1024, 512]
# 		trial: 30     iteration: 7      cost: 2048       mean: 1.496e-01       std error: 1.416e-04       true error: 3.271e-04       time 3745            sample sizes [4096, 4096, 512, 256]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.500e-01       std error: 1.717e-04       true error: 3.756e-05       time 3758            sample sizes [4096, 2048, 1024, 512]
# 		trial: 40     iteration: 7      cost: 2048       mean: 1.498e-01       std error: 1.663e-04       true error: 1.139e-04       time 3770            sample sizes [4096, 4096, 512, 256]
# 		trial: 45     iteration: 8      cost: 2048       mean: 1.500e-01       std error: 1.681e-04       true error: 6.776e-05       time 3782            sample sizes [4096, 2048, 1024, 512]
# 	IGP    DNet     Fast  DSI $\alpha=2$, 	 initial_sample_size = [1024, 512, 256, 128], 	initial cost = 512.0
# 		trial: 0      iteration: 7      cost: 2048       mean: 1.501e-01       std error: 2.269e-04       true error: 1.136e-04       time 3795            sample sizes [4096, 4096, 512, 256]
# 		trial: 5      iteration: 7      cost: 2048       mean: 1.499e-01       std error: 2.057e-04       true error: 4.037e-05       time 3808            sample sizes [4096, 4096, 512, 256]
# 		trial: 10     iteration: 7      cost: 2048       mean: 1.498e-01       std error: 2.293e-04       true error: 1.101e-04       time 3821            sample sizes [4096, 4096, 512, 256]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.499e-01       std error: 2.229e-04       true error: 4.430e-05       time 3833            sample sizes [4096, 2048, 1024, 512]
# 		trial: 20     iteration: 8      cost: 2048       mean: 1.499e-01       std error: 2.240e-04       true error: 3.766e-06       time 3846            sample sizes [4096, 2048, 1024, 512]
# 		trial: 25     iteration: 7      cost: 2048       mean: 1.499e-01       std error: 2.254e-04       true error: 8.018e-05       time 3859            sample sizes [8192, 2048, 512, 256]
# 		trial: 30     iteration: 8      cost: 2048       mean: 1.500e-01       std error: 2.370e-04       true error: 5.847e-05       time 3871            sample sizes [4096, 2048, 1024, 512]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.497e-01       std error: 2.438e-04       true error: 2.665e-04       time 3883            sample sizes [4096, 2048, 1024, 512]
# 		trial: 40     iteration: 8      cost: 2048       mean: 1.499e-01       std error: 3.048e-04       true error: 2.922e-05       time 3896            sample sizes [4096, 2048, 1024, 512]
# 		trial: 45     iteration: 8      cost: 2048       mean: 1.498e-01       std error: 2.212e-04       true error: 1.050e-04       time 3908            sample sizes [4096, 2048, 1024, 512]
# 	IGP    DNet     Fast  DSI $\alpha=3$, 	 initial_sample_size = [1024, 512, 256, 128], 	initial cost = 512.0
# 		trial: 0      iteration: 8      cost: 2048       mean: 1.500e-01       std error: 1.852e-04       true error: 1.701e-05       time 3921            sample sizes [4096, 2048, 1024, 512]
# 		trial: 5      iteration: 8      cost: 2048       mean: 1.499e-01       std error: 1.849e-04       true error: 4.173e-05       time 3934            sample sizes [4096, 2048, 1024, 512]
# 		trial: 10     iteration: 8      cost: 2048       mean: 1.500e-01       std error: 2.438e-04       true error: 9.232e-05       time 3947            sample sizes [4096, 2048, 1024, 512]
# 		trial: 15     iteration: 7      cost: 2048       mean: 1.500e-01       std error: 2.983e-04       true error: 3.964e-05       time 3960            sample sizes [4096, 4096, 512, 256]
# 		trial: 20     iteration: 7      cost: 2048       mean: 1.498e-01       std error: 2.133e-04       true error: 1.852e-04       time 3973            sample sizes [4096, 4096, 512, 256]
# 		trial: 25     iteration: 7      cost: 2048       mean: 1.501e-01       std error: 3.264e-04       true error: 1.556e-04       time 3987            sample sizes [8192, 2048, 512, 256]
# 		trial: 30     iteration: 7      cost: 2048       mean: 1.499e-01       std error: 1.799e-04       true error: 1.228e-05       time 4001            sample sizes [4096, 4096, 512, 256]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.505e-01       std error: 2.232e-04       true error: 5.300e-04       time 4013            sample sizes [4096, 2048, 1024, 512]
# 		trial: 40     iteration: 8      cost: 2048       mean: 1.500e-01       std error: 2.283e-04       true error: 1.091e-04       time 4026            sample sizes [4096, 2048, 1024, 512]
# 		trial: 45     iteration: 7      cost: 2048       mean: 1.499e-01       std error: 2.331e-04       true error: 2.437e-05       time 4040            sample sizes [4096, 4096, 512, 256]
# 	IGP    DNet     Fast  DSI $\alpha=4$, 	 initial_sample_size = [1024, 512, 256, 128], 	initial cost = 512.0
# 		trial: 0      iteration: 7      cost: 2048       mean: 1.501e-01       std error: 2.661e-04       true error: 1.518e-04       time 4054            sample sizes [8192, 2048, 512, 256]
# 		trial: 5      iteration: 7      cost: 2048       mean: 1.501e-01       std error: 2.313e-04       true error: 1.122e-04       time 4068            sample sizes [4096, 4096, 512, 256]
# 		trial: 10     iteration: 8      cost: 2048       mean: 1.502e-01       std error: 2.235e-04       true error: 2.955e-04       time 4081            sample sizes [4096, 2048, 1024, 512]
# 		trial: 15     iteration: 7      cost: 2048       mean: 1.503e-01       std error: 3.826e-04       true error: 3.418e-04       time 4095            sample sizes [4096, 4096, 512, 256]
# 		trial: 20     iteration: 7      cost: 2048       mean: 1.497e-01       std error: 2.606e-04       true error: 2.600e-04       time 4110            sample sizes [8192, 2048, 512, 256]
# 		trial: 25     iteration: 8      cost: 2048       mean: 1.499e-01       std error: 2.256e-04       true error: 5.304e-05       time 4124            sample sizes [4096, 2048, 1024, 512]
# 		trial: 30     iteration: 7      cost: 2048       mean: 1.499e-01       std error: 1.899e-04       true error: 5.008e-05       time 4138            sample sizes [4096, 4096, 512, 256]
# 		trial: 35     iteration: 7      cost: 2048       mean: 1.500e-01       std error: 2.087e-04       true error: 3.729e-05       time 4153            sample sizes [8192, 2048, 512, 256]
# 		trial: 40     iteration: 7      cost: 2048       mean: 1.496e-01       std error: 2.646e-04       true error: 3.261e-04       time 4167            sample sizes [4096, 4096, 512, 256]
# 		trial: 45     iteration: 7      cost: 2048       mean: 1.499e-01       std error: 2.838e-04       true error: 2.236e-05       time 4182            sample sizes [4096, 4096, 512, 256]
# 	MTGP   DNet     Fast  DSI $\alpha=1$ Greedy, 	 initial_sample_size = [1024, 512, 256, 128], 	initial cost = 512.0
# 		trial: 0      iteration: 7      cost: 2048       mean: 1.497e-01       std error: 1.251e-04       true error: 2.034e-04       time 4200            sample sizes [4096, 1024, 512, 1024]
# 		trial: 5      iteration: 7      cost: 2048       mean: 1.493e-01       std error: 1.437e-04       true error: 5.922e-04       time 4222            sample sizes [4096, 1024, 512, 1024]
# 		trial: 10     iteration: 7      cost: 2048       mean: 1.501e-01       std error: 1.704e-04       true error: 1.693e-04       time 4244            sample sizes [4096, 1024, 512, 1024]
# 		trial: 15     iteration: 7      cost: 2048       mean: 1.496e-01       std error: 1.466e-04       true error: 3.536e-04       time 4271            sample sizes [4096, 1024, 512, 1024]
# 		trial: 20     iteration: 7      cost: 2048       mean: 1.498e-01       std error: 1.383e-04       true error: 1.750e-04       time 4296            sample sizes [4096, 1024, 512, 1024]
# 		trial: 25     iteration: 7      cost: 2048       mean: 1.513e-01       std error: 3.550e-04       true error: 1.409e-03       time 4321            sample sizes [4096, 1024, 512, 1024]
# 		trial: 30     iteration: 7      cost: 2048       mean: 1.466e-01       std error: 1.184e-04       true error: 3.357e-03       time 4348            sample sizes [2048, 1024, 2048, 512]
# 		trial: 35     iteration: 7      cost: 2048       mean: 1.502e-01       std error: 2.225e-04       true error: 2.595e-04       time 4374            sample sizes [4096, 1024, 512, 1024]
# 		trial: 40     iteration: 7      cost: 2048       mean: 1.496e-01       std error: 1.504e-04       true error: 3.753e-04       time 4397            sample sizes [4096, 1024, 512, 1024]
# 		trial: 45     iteration: 7      cost: 2048       mean: 1.500e-01       std error: 1.317e-04       true error: 4.829e-05       time 4419            sample sizes [4096, 1024, 512, 1024]
# 	MTGP   DNet     Fast  DSI $\alpha=2$ Greedy, 	 initial_sample_size = [1024, 512, 256, 128], 	initial cost = 512.0
# 		trial: 0      iteration: 6      cost: 2048       mean: 1.514e-01       std error: 1.466e-03       true error: 1.426e-03       time 4446            sample sizes [4096, 2048, 1024, 512]
# 		trial: 5      iteration: 5      cost: 2048       mean: 1.475e-01       std error: 7.551e-04       true error: 2.488e-03       time 4470            sample sizes [2048, 4096, 512, 512]
# 		trial: 10     iteration: 5      cost: 2048       mean: 1.473e-01       std error: 5.938e-04       true error: 2.598e-03       time 4491            sample sizes [2048, 2048, 2048, 256]
# 		trial: 15     iteration: 7      cost: 2048       mean: 1.517e-01       std error: 7.005e-04       true error: 1.739e-03       time 4519            sample sizes [2048, 4096, 1024, 256]
# 		trial: 20     iteration: 6      cost: 2048       mean: 1.497e-01       std error: 1.235e-03       true error: 2.276e-04       time 4547            sample sizes [4096, 2048, 1024, 512]
# 		trial: 25     iteration: 5      cost: 2048       mean: 1.467e-01       std error: 6.604e-04       true error: 3.234e-03       time 4575            sample sizes [2048, 2048, 2048, 256]
# 		trial: 30     iteration: 6      cost: 2048       mean: 1.489e-01       std error: 9.149e-04       true error: 1.042e-03       time 4606            sample sizes [4096, 2048, 1024, 512]
# 		trial: 35     iteration: 5      cost: 2048       mean: 1.507e-01       std error: 8.995e-04       true error: 7.540e-04       time 4636            sample sizes [2048, 1024, 1024, 1024]
# 		trial: 40     iteration: 6      cost: 2048       mean: 1.408e-01       std error: 1.174e-03       true error: 9.101e-03       time 4659            sample sizes [2048, 4096, 1024, 256]
# 		trial: 45     iteration: 5      cost: 2048       mean: 1.471e-01       std error: 8.219e-04       true error: 2.820e-03       time 4686            sample sizes [4096, 2048, 1024, 512]
# 	MTGP   DNet     Fast  DSI $\alpha=3$ Greedy, 	 initial_sample_size = [1024, 512, 256, 128], 	initial cost = 512.0
# 		trial: 0      iteration: 6      cost: 2048       mean: 1.438e-01       std error: 1.532e-03       true error: 6.092e-03       time 4709            sample sizes [4096, 2048, 1024, 512]
# 		trial: 5      iteration: 6      cost: 2048       mean: 1.519e-01       std error: 3.111e-03       true error: 1.972e-03       time 4751            sample sizes [8192, 2048, 512, 256]
# 		trial: 10     iteration: 6      cost: 2048       mean: 1.461e-01       std error: 4.705e-03       true error: 3.795e-03       time 4794            sample sizes [4096, 1024, 2048, 256]
# 		trial: 15     iteration: 6      cost: 2048       mean: 1.440e-01       std error: 6.223e-03       true error: 5.941e-03       time 4826            sample sizes [4096, 2048, 1024, 512]
# 		trial: 20     iteration: 6      cost: 2048       mean: 1.408e-01       std error: 2.632e-03       true error: 9.090e-03       time 4861            sample sizes [4096, 2048, 1024, 512]
# 		trial: 25     iteration: 6      cost: 2048       mean: 1.340e-01       std error: 1.410e-03       true error: 1.596e-02       time 4896            sample sizes [2048, 2048, 512, 1024]
# 		trial: 30     iteration: 5      cost: 2048       mean: 1.494e-01       std error: 3.238e-03       true error: 5.800e-04       time 4934            sample sizes [8192, 1024, 1024, 256]
# 		trial: 35     iteration: 6      cost: 2048       mean: 1.538e-01       std error: 3.248e-03       true error: 3.877e-03       time 4966            sample sizes [8192, 2048, 512, 256]
# 		trial: 40     iteration: 6      cost: 2048       mean: 1.351e-01       std error: 4.112e-03       true error: 1.483e-02       time 5000            sample sizes [2048, 4096, 512, 512]
# 		trial: 45     iteration: 5      cost: 2048       mean: 1.527e-01       std error: 1.956e-03       true error: 2.763e-03       time 5032            sample sizes [4096, 4096, 512, 256]
# 	MTGP   DNet     Fast  DSI $\alpha=4$ Greedy, 	 initial_sample_size = [1024, 512, 256, 128], 	initial cost = 512.0
# 		trial: 0      iteration: 6      cost: 2048       mean: 1.418e-01       std error: 2.020e-03       true error: 8.160e-03       time 5065            sample sizes [2048, 1024, 2048, 512]
# 		trial: 5      iteration: 5      cost: 2048       mean: 1.521e-01       std error: 2.431e-03       true error: 2.162e-03       time 5105            sample sizes [2048, 4096, 512, 512]
# 		trial: 10     iteration: 5      cost: 2048       mean: 1.372e-01       std error: 2.326e-03       true error: 1.269e-02       time 5146            sample sizes [2048, 2048, 2048, 256]
# 		trial: 15     iteration: 6      cost: 2048       mean: 1.354e-01       std error: 4.182e-03       true error: 1.456e-02       time 5180            sample sizes [4096, 2048, 1024, 512]
# 		trial: 20     iteration: 6      cost: 2048       mean: 1.386e-01       std error: 4.541e-03       true error: 1.130e-02       time 5234            sample sizes [2048, 4096, 1024, 256]
# 		trial: 25     iteration: 5      cost: 2048       mean: 1.427e-01       std error: 3.935e-03       true error: 7.244e-03       time 5269            sample sizes [2048, 4096, 512, 512]
# 		trial: 30     iteration: 5      cost: 2048       mean: 1.454e-01       std error: 5.279e-03       true error: 4.543e-03       time 5303            sample sizes [8192, 1024, 512, 512]
# 		trial: 35     iteration: 6      cost: 2048       mean: 1.514e-01       std error: 5.381e-03       true error: 1.470e-03       time 5336            sample sizes [4096, 4096, 512, 256]
# 		trial: 40     iteration: 6      cost: 2048       mean: 2.985e-01       std error: 1.313e-02       true error: 1.486e-01       time 5387            sample sizes [2048, 4096, 512, 512]
# 		trial: 45     iteration: 5      cost: 2048       mean: 1.418e-01       std error: 3.077e-03       true error: 8.154e-03       time 5446            sample sizes [2048, 2048, 2048, 256]

# %% [markdown]
# ## Analysis

# %%
fig,ax = pyplot.subplots(nrows=1,ncols=1,figsize=(9,5))
for i,name in enumerate(names):
    vals = costs[i]-max_budgets[:,None]
    q_low = np.nanquantile(vals,.1,axis=1)
    q_med = np.nanquantile(vals,.5,axis=1)
    q_high = np.nanquantile(vals,.9,axis=1)
    ax.plot(max_budgets,q_med,'-o',label=name,linewidth=LW,color=COLORS[i])
    ax.fill_between(max_budgets,q_low,q_high,alpha=alpha,color=COLORS[i])
ax.legend(frameon=False,fontsize="large",bbox_to_anchor=(-.25,1))
ax.set_xlabel("max_budgets",fontsize="large")
ax.set_ylabel("median (max_budget - costs)",fontsize="large");
print("above 0 means it is over budget, below 0 means it is within the budget")
# Out:
# above 0 means it is over budget, below 0 means it is within the budget

# %%
nrows = len(max_budgets)
ncols = len(names)
fig,ax = pyplot.subplots(nrows=nrows,ncols=ncols,figsize=(6*ncols,5*nrows),sharey="row",sharex=True)
for i in range(nrows):
    for j in range(ncols):
        bplot = ax[i,j].boxplot(samples_per_level[j,i,:,:],orientation="vertical",label=names[j],patch_artist=True,notch=False);
        for _attr in ['boxes','means']:
            for patch in bplot[_attr]: patch.set_facecolor(COLORS[j])
        for _attr in ['medians','fliers','whiskers','medians','means','boxes']:
            for patch in bplot[_attr]: patch.set_color(COLORS[j])
    ax[i,0].set_ylabel("budget = %d"%max_budgets[i],fontsize="xx-large")
for j in range(ncols):
    ax[0,j].set_title(names[j],fontsize="xx-large")
    ax[-1,j].set_xlabel("level")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize="xx-large")
#fig.tight_layout()
fig.savefig(dataroot+"sample_allocation.pdf",transparent=True,bbox_inches="tight")

# %%
fig,ax = pyplot.subplots(nrows=1,ncols=2,figsize=(5*2,5),sharey=True,sharex=True)
for i,name in enumerate(names):
    for j,(vals,linestyle,alpha) in enumerate(zip([true_errors[i],std_errors[i]],['-o','--o'],[.1,.2])):
        q_low = np.nanquantile(vals,.25,axis=1)
        q_med = np.nanquantile(vals,.5,axis=1)
        q_high = np.nanquantile(vals,.75,axis=1)
        ax[j].plot(max_budgets,q_med,linestyle,label=name,linewidth=LW,alpha=1,color=COLORS[i])
        #ax[j].scatter(costs[i],vals,color=COLORS[i])
        ax[j].fill_between(max_budgets,q_low,q_high,alpha=alpha,color=COLORS[i])
ax[0].legend(frameon=False,fontsize="large",bbox_to_anchor=(-.5,1))
ax[0].set_yscale("log",base=10)
ax[0].set_xscale("log",base=2)
ax[0].set_ylabel("true_errors",fontsize="large")
ax[1].set_ylabel("standard error")
for j in range(2):
    ax[j].set_xlabel("max_budgets",fontsize="large")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize="large");
fig.savefig(dataroot+"convergence_by_error.pdf",transparent=True,bbox_inches="tight")
fig,ax = pyplot.subplots(nrows=1,ncols=len(names),figsize=(5*len(names),5+1),sharey=True,sharex=True)
for i,name in enumerate(names):
    for j,(error_metric,vals,linestyle,alpha) in enumerate(zip(["true error","standard error"],[true_errors[i],std_errors[i]],['-o','--o'],[.1,.2])):
        q_low = np.nanquantile(vals,.25,axis=1)
        q_med = np.nanquantile(vals,.5,axis=1)
        q_high = np.nanquantile(vals,.75,axis=1)
        ax[i].plot(max_budgets,q_med,linestyle,label=error_metric,linewidth=LW,alpha=1,color=COLORS[i])
        #ax[j].scatter(costs[i],vals,color=COLORS[i])
        ax[i].fill_between(max_budgets,q_low,q_high,alpha=alpha,color=COLORS[i])
        ax[i].set_title(name,fontsize="large")
ax[0].legend(frameon=False,fontsize="large")
ax[0].set_yscale("log",base=10)
ax[0].set_xscale("log",base=2)
for j in range(len(names)):
    ax[j].set_xlabel("max_budgets",fontsize="large")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize="large");
fig.savefig(dataroot+"convergence_by_method.pdf",transparent=True,bbox_inches="tight")

# %%
nrows = len(max_budgets)
ncols = len(names)
ncols = fig,ax = pyplot.subplots(nrows=nrows,ncols=ncols,figsize=(ncols*5,nrows*4),sharex=True,sharey=True)
for i,name in enumerate(names):
    for j in range(len(max_budgets)):
        ax[j,i].hist(np.log10(true_errors[i,j]),label=name,density=True,bins=10,alpha=.5,color=COLORS[i]) 
    ax[0,i].set_title(name,fontsize="x-large")
    ax[-1,i].set_xlabel(r"$\log_{10}(\mathrm{error})$",fontsize="x-large")
for j in range(len(max_budgets)):
    ax[j,0].set_ylabel("budget = %d"%max_budgets[j],fontsize="x-large")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize="x-large")#,ncol=len(names))
#ax[0].set_ylabel("density",fontsize="x-large")
#fig.tight_layout()
#ax[0].set_xscale("log",base=10)
fig.savefig(dataroot+"densities.pdf",transparent=True,bbox_inches="tight")

# %%
ncols = len(names) 
nrows = len(max_budgets)
fig,ax = pyplot.subplots(nrows=nrows,ncols=ncols,figsize=(5*ncols,5*nrows),sharex=True,sharey=True)
for i,name in enumerate(names):
    for j in range(len(max_budgets)):
        ax[j,i].scatter(true_errors[i,j],std_errors[i,j],label=name,color=COLORS[i])
        ax[j,i].axline(xy1=(0,0),slope=1,color="k")
    ax[-1,i].set_ylabel("std errors",fontsize="large")
    ax[0,i].set_title(name,fontsize='x-large')
for j in range(len(max_budgets)):
    ax[j,0].set_ylabel("budget = %d"%max_budgets[j])
ax[0,0].set_xscale("log",base=10)
ax[0,0].set_yscale("log",base=10)
for j in range(len(max_budgets)):
    ax[j,0].set_xlabel("true errors",fontsize="large")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize='xx-large')#,ncols=len(max_budgets),)
#ax[j].xaxis.set_tick_params(labelbottom=True)
fig.tight_layout()
fig.savefig(dataroot+"error_scatters.pdf",transparent=True,bbox_inches="tight")
