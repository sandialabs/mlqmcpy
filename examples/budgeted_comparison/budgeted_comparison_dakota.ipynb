# %% [markdown]
# # Budgeted MLMC vs MLQMC

# %% [markdown]
# ## Imports

# %%
import mlqmcpy as mp
from mlqmcpy.problems.dakota.steady_state_diffusion_1d import steady_state_diffusion_1d

# %%
import numpy as np
import qmcpy as qp
import time
import os

# %%
from matplotlib import pyplot
pyplot.style.use("seaborn-v0_8-whitegrid")
COLORS = ['xkcd:purple', 'xkcd:green', 'xkcd:blue', 'xkcd:red', 'xkcd:turquoise', 'xkcd:pink', 'xkcd:brown', 'xkcd:light blue', 'xkcd:teal', 'xkcd:orange']
#pyplot.rcParams['axes.prop_cycle'] = matplotlib.cycler(color=COLORS)
WIDTH = 2*(500/72)
LW = 3
alpha = .2

# %%
from IPython.display import display, HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))
# Out:
# <style>pre { white-space: pre !important; }</style>

# %% [markdown]
# ## Experiment

# %%
force_experiment = False
# problem_dim_levels = (analytic,2,4)
#problem_dim_levels = (borehole,8,2)
#problem_dim_levels = (elliptic,8,4)
#problem_dim_levels = (asian_option,16,8)
problem_dim_levels = (steady_state_diffusion_1d,9,5)
problem,dimension,num_levels = problem_dim_levels
dataroot = "budgeted_comparison_data/comp.%s.d%d.levels%d.DNET.replications/"%(problem.__name__,dimension,num_levels)
if not os.path.exists(dataroot):
    os.makedirs(dataroot)
if not os.path.isfile(dataroot+"data.npy") or force_experiment:
    # parameters 
    max_budgets = 2**np.arange(10,15)
    initial_cost_prop_max_budget = 1/4
    kwargs_fastgp_fit = {"loss_metric":"MLL","stop_crit_improvement_threshold":1e0,"verbose":0}
    refit_igps = True
    refit_mtgps = True
    n_ref = 2**19
    trials = 50
    verbose = max(1,trials//10)
    zip_name_IteratorClass_kwargs = [
        ## MLMC
        ("MLMC    IID",mp.GreedyMLMCIterator,{}),
        ## R-MLQMC
        # ##  LATTICE
        # (r"R-MLQMC Lattice $R=8$",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"replications":8}),
        # (r"R-MLQMC Lattice $R=16$",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"replications":16}),
        # (r"R-MLQMC Lattice $R=32$",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"replications":32}),
        # (r"R-MLQMC Lattice $R=64$",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"replications":64}),
        ##  DNET 
        (r"R-MLQMC DNet $R=8$",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"replications":8}),
        (r"R-MLQMC DNet $R=16$",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"replications":16}),
        (r"R-MLQMC DNet $R=32$",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"replications":32}),
        (r"R-MLQMC DNet $R=64$",mp.GreedyMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"replications":64}),
        ## IGP 
        ##   FAST
        # ##       LATTICE 
        # (r"IGP    Lattice  Fast  SI  $\alpha=2$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"kwargs_fastgp_construct":{"alpha":2},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # (r"IGP    Lattice  Fast  SI  $\alpha=3$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"kwargs_fastgp_construct":{"alpha":3},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # (r"IGP    Lattice  Fast  SI  $\alpha=4$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"kwargs_fastgp_construct":{"alpha":4},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # (r"IGP    Lattice  Fast  SI  $\alpha=5$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"kwargs_fastgp_construct":{"alpha":5},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        ##       DNET
        (r"IGP    DNet     Fast  DSI $\alpha=1$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"kwargs_fastgp_construct":{"alpha":1},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        (r"IGP    DNet     Fast  DSI $\alpha=2$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"kwargs_fastgp_construct":{"alpha":2},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        (r"IGP    DNet     Fast  DSI $\alpha=3$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"kwargs_fastgp_construct":{"alpha":3},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        (r"IGP    DNet     Fast  DSI $\alpha=4$",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"kwargs_fastgp_construct":{"alpha":4},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # ##   SLOW        
        # ##       Lattice
        # (r"IGP    Lattice  Slow  SE",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":False,"kwargs_fastgp_construct":{},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        # ##       DNET 
        # (r"IGP    DNet     Slow  SE",mp.GreedyGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":False,"kwargs_fastgp_construct":{},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_igps}),
        ## MTGP
        ##   FAST 
        # ##       LATTICE
        # (r"MTGP   Lattice  Fast  SI  $\alpha=2$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":2,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # (r"MTGP   Lattice  Fast  SI  $\alpha=3$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":3,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # (r"MTGP   Lattice  Fast  SI  $\alpha=4$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":4,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # (r"MTGP   Lattice  Fast  SI  $\alpha=5$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":5,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        ##       DNET
        # (r"MTGP   DNet     Fast  DSI $\alpha=1$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":1,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # (r"MTGP   DNet     Fast  DSI $\alpha=2$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":2,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # (r"MTGP   DNet     Fast  DSI $\alpha=3$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":3,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # (r"MTGP   DNet     Fast  DSI $\alpha=4$ Greedy",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":True,"budget_scheme":"greedy","kwargs_fastgp_construct":{"alpha":4,"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit,"refit_gps":refit_mtgps}),
        # ##   SLOW
        # ##       LATTICE
        # (r"MTGP   Lattice  Slow  SE",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.Lattice,"fast":False,"budget_scheme":"greedy","kwargs_fastgp_construct":{"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit},"refit_gps":refit_mtgps),
        # ##       DNET
        # (r"MTGP   DNet     Slow  SE",mp.MultiTaskGaussianProcessMLQMCIterator,{"discrete_distribution_type":qp.DigitalNetB2,"fast":False,"budget_scheme":"greedy","kwargs_fastgp_construct":{"rank_factor_task_kernel":num_levels},"kwargs_fastgp_fit":kwargs_fastgp_fit},"refit_gps":refit_mtgps),
    ]
    # experiment
    t0 = time.perf_counter()
    names = [name for (name,IteratorClass,kwargs) in zip_name_IteratorClass_kwargs]
    if hasattr(problem,"exact") and hasattr(problem.exact,"Q") and hasattr(problem.exact.Q,"mean"):
        true_solution = problem.exact.Q.mean(level=num_levels-1)
    else:
        true_solution = problem(num_levels-1,qp.DigitalNetB2(dimension)(n_ref)).mean()
    cost_per_level = 2.**(np.arange(num_levels)-num_levels+1) # Rescale so that finest level has unit cost
    print("max_budgets: %s"%max_budgets)
    print("cost_per_level: %s"%str(cost_per_level))
    print("true_solution = %.5e"%true_solution)
    print()
    costs = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials))
    means = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials))
    std_errors = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials))
    true_errors = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials))
    samples_per_level = np.empty((len(zip_name_IteratorClass_kwargs),len(max_budgets),trials,num_levels),dtype=int)
    for j in range(len(max_budgets)):
        max_budget = max_budgets[j]
        initial_budget = int(initial_cost_prop_max_budget*max_budget)
        print("budget = %d, initial budget = %d"%(max_budget,initial_budget))
        initial_sample_size_og = initial_budget/num_levels/cost_per_level
        for i,(name,IteratorClass,kwargs) in enumerate(zip_name_IteratorClass_kwargs):
            if IteratorClass==mp.GreedyMLQMCIterator:
                initial_sample_size = initial_sample_size_og/kwargs["replications"]
                initial_sample_size = 2**np.ceil(np.log2(initial_sample_size)).astype(int)
                initial_cost = kwargs["replications"]*(initial_sample_size*cost_per_level).sum()
            else:
                initial_sample_size = 2**np.ceil(np.log2(initial_sample_size_og)).astype(int)
                initial_cost = (initial_sample_size*cost_per_level).sum()
            print("\t%s, \t initial_sample_size = %s, \tinitial cost = %.1f"%(name,str(initial_sample_size.tolist()),initial_cost))
            for t in range(trials):
                iterator = IteratorClass(
                    dimension,
                    initial_sample_size = initial_sample_size,
                    cost_per_level = cost_per_level,
                    max_budget = max_budget,
                    **kwargs)
                problem_l_or_ml = problem if isinstance(iterator,mp.MultiTaskGaussianProcessMLQMCIterator) else problem.ml
                problem_tf = (lambda level,x: problem_l_or_ml(level,1-2*np.abs(x-1/2))) if iterator.discrete_distribution_type==qp.Lattice else problem_l_or_ml
                for iter, new_samples in enumerate(iterator):
                    new_results = {level: problem_tf(level,samples) for level,samples in new_samples.items()}
                    iterator.update(new_results)
                costs[i,j,t] = iterator.cost
                means[i,j,t] = iterator.mean
                std_errors[i,j,t] = iterator.standard_error
                true_errors[i,j,t] = np.abs(true_solution-means[i,j,t])
                samples_per_level[i,j,t] = iterator.total_samples_per_level.copy()
                if verbose and t%verbose==0:
                    print("\t\ttrial: %-6d iteration: %-6d cost: %-10d mean: %-15.3e std error: %-15.3e true error: %-15.3e time %-15d sample sizes %s"%\
                    (t,iter,costs[i,j,t],means[i,j,t],std_errors[i,j,t],true_errors[i,j,t],int(np.ceil(time.perf_counter()-t0)),str(samples_per_level[i,j,t].tolist())))
                #import psutil; process = psutil.Process(os.getpid()); print(f"Total program memory: {process.memory_info().rss / (1024 * 1024):.2f} MB")
                del iterator
                import gc
                gc.collect()
        print()
    data = {
        "dimension": dimension,
        "num_levels": num_levels,
        "max_budgets": max_budgets,
        "initial_cost_prop_max_budget": initial_cost_prop_max_budget,
        "names": names,
        "costs": costs,
        "means": means,
        "std_errors": std_errors,
        "samples_per_level": samples_per_level,
        "true_errors": true_errors,
        "kwargs_fastgp_fit": kwargs_fastgp_fit,
        "refit_gps":refit_igps,
        "n_ref":n_ref,
    }
    np.save(dataroot+"data.npy",data)
else:
    data = np.load(dataroot+"data.npy",allow_pickle=True)[()]
    dimension = data["dimension"]
    num_levels = data["num_levels"]
    initial_cost_prop_max_budget = data["initial_cost_prop_max_budget"]
    max_budgets = data["max_budgets"]
    names = data["names"]
    costs = data["costs"]
    means = data["means"]
    std_errors = data["std_errors"]
    true_errors = data["true_errors"]
    kwargs_fastgp_fit = data["kwargs_fastgp_fit"]
    refit_igps = data["refit_gps"]
    samples_per_level = data["samples_per_level"]
    n_ref = data["n_ref"]
    trials = costs.shape[-1]
# Out:
# max_budgets: [ 1024  2048  4096  8192 16384]
# cost_per_level: [0.0625 0.125  0.25   0.5    1.    ]
# true_solution = 1.25233e-01
#
# budget = 1024, initial budget = 256
# 	MLMC    IID, 	 initial_sample_size = [1024, 512, 256, 128, 64], 	initial cost = 320.0
# 		trial: 0      iteration: 6      cost: 1024       mean: 1.251e-01       std error: 6.511e-05       true error: 1.128e-04       time 137             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 5      iteration: 6      cost: 1024       mean: 1.254e-01       std error: 6.536e-05       true error: 1.303e-04       time 156             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 10     iteration: 6      cost: 1024       mean: 1.251e-01       std error: 6.536e-05       true error: 8.376e-05       time 175             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 15     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 6.535e-05       true error: 9.693e-06       time 194             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 20     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 6.598e-05       true error: 2.108e-05       time 213             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 25     iteration: 6      cost: 1024       mean: 1.253e-01       std error: 6.478e-05       true error: 5.046e-05       time 233             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 30     iteration: 6      cost: 1024       mean: 1.253e-01       std error: 6.592e-05       true error: 7.058e-05       time 253             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 35     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 6.544e-05       true error: 6.859e-05       time 272             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 40     iteration: 6      cost: 1024       mean: 1.253e-01       std error: 6.616e-05       true error: 3.455e-05       time 292             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 45     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 6.567e-05       true error: 4.914e-06       time 311             sample sizes [8192, 2048, 512, 128, 64]
# 	R-MLQMC DNet $R=8$, 	 initial_sample_size = [128, 64, 32, 16, 8], 	initial cost = 320.0
# 		trial: 0      iteration: 7      cost: 1024       mean: 1.252e-01       std error: 4.887e-07       true error: 4.979e-07       time 331             sample sizes [8192, 1024, 512, 256, 128]
# 		trial: 5      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.756e-07       true error: 8.195e-08       time 354             sample sizes [2048, 2048, 1024, 512, 128]
# 		trial: 10     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.594e-07       true error: 2.278e-07       time 376             sample sizes [2048, 2048, 1024, 512, 128]
# 		trial: 15     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.007e-07       true error: 1.662e-07       time 399             sample sizes [4096, 1024, 1024, 512, 128]
# 		trial: 20     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 9.848e-08       true error: 1.622e-07       time 421             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 25     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 9.198e-08       true error: 4.377e-08       time 444             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 30     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.743e-07       true error: 9.351e-08       time 467             sample sizes [2048, 2048, 1024, 512, 128]
# 		trial: 35     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 8.141e-08       true error: 8.465e-08       time 490             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 40     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.324e-07       true error: 5.468e-08       time 513             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 45     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.391e-07       true error: 7.041e-08       time 535             sample sizes [4096, 2048, 1024, 256, 128]
# 	R-MLQMC DNet $R=16$, 	 initial_sample_size = [64, 32, 16, 8, 4], 	initial cost = 320.0
# 		trial: 0      iteration: 6      cost: 1024       mean: 1.252e-01       std error: 4.521e-07       true error: 1.927e-07       time 557             sample sizes [4096, 4096, 512, 128, 64]
# 		trial: 5      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.189e-07       true error: 5.990e-08       time 581             sample sizes [2048, 2048, 1024, 512, 128]
# 		trial: 10     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.273e-07       true error: 6.959e-07       time 603             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 15     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 2.670e-07       true error: 5.858e-07       time 626             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 20     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.671e-07       true error: 5.467e-07       time 650             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 25     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 4.647e-07       true error: 4.832e-07       time 678             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 30     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.364e-07       true error: 3.489e-07       time 701             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 35     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 6.147e-07       true error: 1.473e-07       time 725             sample sizes [8192, 2048, 512, 128, 64]
# 		trial: 40     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.684e-07       true error: 5.880e-07       time 749             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 45     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 4.947e-07       true error: 5.721e-07       time 775             sample sizes [4096, 2048, 1024, 256, 128]
# 	R-MLQMC DNet $R=32$, 	 initial_sample_size = [32, 16, 8, 4, 2], 	initial cost = 320.0
# 		trial: 0      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 6.149e-07       true error: 5.786e-07       time 800             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 5      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 8.087e-07       true error: 1.260e-06       time 823             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 10     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 5.153e-07       true error: 6.089e-07       time 849             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 15     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.060e-06       true error: 1.700e-06       time 872             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 20     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 6.591e-07       true error: 1.607e-07       time 898             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 25     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 7.019e-07       true error: 1.391e-07       time 923             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 30     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 6.387e-07       true error: 7.356e-07       time 947             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 35     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 6.229e-07       true error: 2.064e-08       time 971             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 40     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.020e-06       true error: 4.668e-07       time 996             sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 45     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 7.405e-07       true error: 1.057e-06       time 1023            sample sizes [4096, 2048, 1024, 256, 128]
# 	R-MLQMC DNet $R=64$, 	 initial_sample_size = [16, 8, 4, 2, 1], 	initial cost = 320.0
# 		trial: 0      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.942e-06       true error: 4.321e-07       time 1046            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 5      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.965e-06       true error: 6.069e-07       time 1072            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 10     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 2.126e-06       true error: 6.281e-07       time 1095            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 15     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.800e-06       true error: 1.391e-06       time 1119            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 20     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 2.003e-06       true error: 5.812e-07       time 1143            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 25     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.409e-06       true error: 8.073e-07       time 1167            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 30     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.274e-06       true error: 1.072e-06       time 1190            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 35     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 2.016e-06       true error: 1.927e-06       time 1213            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 40     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.480e-06       true error: 4.165e-07       time 1236            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 45     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.673e-06       true error: 1.369e-06       time 1259            sample sizes [4096, 2048, 1024, 256, 128]
# 	IGP    DNet     Fast  DSI $\alpha=1$, 	 initial_sample_size = [1024, 512, 256, 128, 64], 	initial cost = 320.0
# 		trial: 0      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.648e-07       true error: 1.290e-08       time 1283            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 5      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.415e-07       true error: 3.948e-10       time 1310            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 10     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 2.822e-07       true error: 1.025e-08       time 1337            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 15     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.396e-07       true error: 1.486e-08       time 1365            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 20     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.709e-07       true error: 1.147e-08       time 1392            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 25     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.795e-07       true error: 2.221e-08       time 1420            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 30     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 4.019e-07       true error: 6.198e-09       time 1448            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 35     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.581e-07       true error: 1.625e-08       time 1476            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 40     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.632e-07       true error: 3.063e-08       time 1504            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 45     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 2.999e-07       true error: 3.584e-08       time 1533            sample sizes [4096, 2048, 1024, 256, 128]
# 	IGP    DNet     Fast  DSI $\alpha=2$, 	 initial_sample_size = [1024, 512, 256, 128, 64], 	initial cost = 320.0
# 		trial: 0      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.950e-07       true error: 5.226e-09       time 1561            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 5      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.999e-07       true error: 1.636e-09       time 1589            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 10     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 4.778e-07       true error: 5.976e-08       time 1616            sample sizes [2048, 2048, 2048, 128, 64]
# 		trial: 15     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 4.904e-07       true error: 1.481e-09       time 1644            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 20     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 5.661e-07       true error: 6.290e-09       time 1671            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 25     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.297e-07       true error: 5.008e-10       time 1699            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 30     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 3.469e-07       true error: 3.176e-11       time 1726            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 35     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 4.913e-07       true error: 4.343e-08       time 1752            sample sizes [2048, 2048, 2048, 128, 64]
# 		trial: 40     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 4.666e-07       true error: 1.882e-08       time 1780            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 45     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 6.605e-07       true error: 2.390e-09       time 1807            sample sizes [4096, 2048, 1024, 256, 128]
# 	IGP    DNet     Fast  DSI $\alpha=3$, 	 initial_sample_size = [1024, 512, 256, 128, 64], 	initial cost = 320.0
# 		trial: 0      iteration: 6      cost: 1024       mean: 1.252e-01       std error: 1.287e-07       true error: 6.670e-11       time 1834            sample sizes [2048, 4096, 1024, 128, 64]
# 		trial: 5      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.265e-07       true error: 4.981e-08       time 1861            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 10     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.250e-07       true error: 1.582e-09       time 1889            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 15     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.179e-07       true error: 1.975e-08       time 1915            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 20     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.100e-07       true error: 3.587e-09       time 1942            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 25     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 1.472e-07       true error: 8.279e-08       time 1969            sample sizes [2048, 4096, 1024, 128, 64]
# 		trial: 30     iteration: 7      cost: 1024       mean: 1.252e-01       std error: 1.634e-07       true error: 9.300e-08       time 1996            sample sizes [2048, 4096, 512, 256, 128]
# 		trial: 35     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.674e-07       true error: 5.575e-09       time 2022            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 40     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 2.280e-07       true error: 1.531e-08       time 2047            sample sizes [2048, 4096, 1024, 128, 64]
# 		trial: 45     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.437e-07       true error: 1.084e-08       time 2073            sample sizes [4096, 2048, 1024, 256, 128]
# 	IGP    DNet     Fast  DSI $\alpha=4$, 	 initial_sample_size = [1024, 512, 256, 128, 64], 	initial cost = 320.0
# 		trial: 0      iteration: 6      cost: 1024       mean: 1.252e-01       std error: 1.322e-07       true error: 8.176e-09       time 2098            sample sizes [2048, 4096, 1024, 128, 64]
# 		trial: 5      iteration: 8      cost: 1024       mean: 1.252e-01       std error: 9.994e-08       true error: 3.591e-08       time 2125            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 10     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 2.267e-07       true error: 4.538e-08       time 2151            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 15     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 1.240e-07       true error: 4.058e-08       time 2177            sample sizes [2048, 4096, 1024, 128, 64]
# 		trial: 20     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 1.432e-07       true error: 7.034e-09       time 2204            sample sizes [2048, 4096, 1024, 128, 64]
# 		trial: 25     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.412e-07       true error: 3.707e-09       time 2233            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 30     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.112e-07       true error: 2.404e-08       time 2260            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 35     iteration: 6      cost: 1024       mean: 1.252e-01       std error: 1.213e-07       true error: 1.128e-09       time 2287            sample sizes [2048, 2048, 2048, 128, 64]
# 		trial: 40     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.457e-07       true error: 2.103e-09       time 2315            sample sizes [4096, 2048, 1024, 256, 128]
# 		trial: 45     iteration: 8      cost: 1024       mean: 1.252e-01       std error: 1.759e-07       true error: 3.600e-09       time 2343            sample sizes [4096, 2048, 1024, 256, 128]
#
# budget = 2048, initial budget = 512
# 	MLMC    IID, 	 initial_sample_size = [2048, 1024, 512, 256, 128], 	initial cost = 640.0
# 		trial: 0      iteration: 6      cost: 2048       mean: 1.252e-01       std error: 4.656e-05       true error: 1.459e-05       time 2369            sample sizes [16384, 4096, 1024, 256, 128]
# 		trial: 5      iteration: 6      cost: 2048       mean: 1.253e-01       std error: 4.631e-05       true error: 5.627e-05       time 2392            sample sizes [16384, 4096, 1024, 256, 128]
# 		trial: 10     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 4.635e-05       true error: 6.861e-05       time 2414            sample sizes [16384, 4096, 1024, 256, 128]
# 		trial: 15     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 4.619e-05       true error: 3.489e-05       time 2437            sample sizes [16384, 4096, 1024, 256, 128]
# 		trial: 20     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 4.654e-05       true error: 2.858e-05       time 2459            sample sizes [16384, 4096, 1024, 256, 128]
# 		trial: 25     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 4.614e-05       true error: 6.945e-05       time 2482            sample sizes [16384, 4096, 1024, 256, 128]
# 		trial: 30     iteration: 6      cost: 2048       mean: 1.253e-01       std error: 4.611e-05       true error: 9.629e-05       time 2504            sample sizes [16384, 4096, 1024, 256, 128]
# 		trial: 35     iteration: 6      cost: 2048       mean: 1.253e-01       std error: 4.634e-05       true error: 2.897e-05       time 2526            sample sizes [16384, 4096, 1024, 256, 128]
# 		trial: 40     iteration: 6      cost: 2048       mean: 1.253e-01       std error: 4.654e-05       true error: 7.565e-05       time 2549            sample sizes [16384, 4096, 1024, 256, 128]
# 		trial: 45     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 4.626e-05       true error: 2.710e-05       time 2571            sample sizes [16384, 4096, 1024, 256, 128]
# 	R-MLQMC DNet $R=8$, 	 initial_sample_size = [256, 128, 64, 32, 16], 	initial cost = 640.0
# 		trial: 0      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 4.590e-08       true error: 1.258e-07       time 2595            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 5      iteration: 7      cost: 2048       mean: 1.252e-01       std error: 9.148e-08       true error: 7.262e-08       time 2621            sample sizes [4096, 8192, 1024, 512, 256]
# 		trial: 10     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 4.522e-08       true error: 4.142e-08       time 2647            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 4.100e-08       true error: 1.314e-08       time 2673            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 20     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.516e-08       true error: 7.221e-08       time 2699            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 25     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 4.890e-08       true error: 3.322e-08       time 2725            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 30     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 3.817e-08       true error: 2.972e-08       time 2752            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 35     iteration: 7      cost: 2048       mean: 1.252e-01       std error: 1.120e-07       true error: 2.588e-07       time 2778            sample sizes [4096, 8192, 1024, 512, 256]
# 		trial: 40     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.959e-08       true error: 4.678e-08       time 2804            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 45     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 3.567e-08       true error: 8.704e-11       time 2830            sample sizes [4096, 4096, 2048, 1024, 256]
# 	R-MLQMC DNet $R=16$, 	 initial_sample_size = [128, 64, 32, 16, 8], 	initial cost = 640.0
# 		trial: 0      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 8.127e-08       true error: 1.396e-07       time 2857            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 5      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.098e-07       true error: 2.768e-08       time 2883            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 10     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.638e-07       true error: 1.002e-07       time 2909            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.451e-07       true error: 5.351e-09       time 2936            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 20     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.033e-07       true error: 8.272e-08       time 2962            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 25     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 9.232e-08       true error: 5.054e-08       time 2988            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 30     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.413e-08       true error: 3.854e-08       time 3015            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.090e-07       true error: 6.605e-08       time 3041            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 40     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.740e-08       true error: 2.457e-08       time 3067            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 45     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 8.619e-08       true error: 2.123e-07       time 3094            sample sizes [8192, 4096, 2048, 512, 256]
# 	R-MLQMC DNet $R=32$, 	 initial_sample_size = [64, 32, 16, 8, 4], 	initial cost = 640.0
# 		trial: 0      iteration: 7      cost: 2048       mean: 1.252e-01       std error: 3.568e-07       true error: 1.908e-07       time 3120            sample sizes [4096, 8192, 1024, 512, 256]
# 		trial: 5      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.586e-07       true error: 1.735e-07       time 3146            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 10     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.580e-07       true error: 5.927e-08       time 3172            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.166e-07       true error: 7.720e-08       time 3198            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 20     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.417e-07       true error: 9.075e-08       time 3225            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 25     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.304e-07       true error: 1.791e-07       time 3251            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 30     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.071e-07       true error: 2.064e-07       time 3277            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.888e-07       true error: 7.562e-07       time 3303            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 40     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 3.218e-07       true error: 2.685e-07       time 3329            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 45     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.041e-07       true error: 2.433e-07       time 3355            sample sizes [8192, 4096, 2048, 512, 256]
# 	R-MLQMC DNet $R=64$, 	 initial_sample_size = [32, 16, 8, 4, 2], 	initial cost = 640.0
# 		trial: 0      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.192e-07       true error: 5.606e-07       time 3381            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 5      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.017e-07       true error: 4.708e-07       time 3407            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 10     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 8.238e-07       true error: 1.853e-08       time 3433            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 8.291e-07       true error: 2.376e-07       time 3459            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 20     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 6.793e-07       true error: 1.804e-07       time 3486            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 25     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 6.010e-07       true error: 1.795e-07       time 3512            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 30     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.888e-07       true error: 1.608e-07       time 3538            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.996e-07       true error: 2.856e-08       time 3565            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 40     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 6.734e-07       true error: 4.250e-07       time 3591            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 45     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 6.881e-07       true error: 1.510e-07       time 3618            sample sizes [8192, 4096, 2048, 512, 256]
# 	IGP    DNet     Fast  DSI $\alpha=1$, 	 initial_sample_size = [2048, 1024, 512, 256, 128], 	initial cost = 640.0
# 		trial: 0      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.167e-07       true error: 3.763e-09       time 3645            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 5      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.168e-07       true error: 7.428e-09       time 3677            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 10     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.145e-07       true error: 4.947e-10       time 3708            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.175e-07       true error: 5.363e-09       time 3740            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 20     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.869e-07       true error: 7.530e-09       time 3772            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 25     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.182e-07       true error: 8.122e-10       time 3803            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 30     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.145e-07       true error: 7.216e-10       time 3835            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.866e-07       true error: 1.002e-09       time 3867            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 40     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.162e-07       true error: 2.257e-09       time 3899            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 45     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.868e-07       true error: 1.550e-09       time 3930            sample sizes [8192, 4096, 2048, 512, 256]
# 	IGP    DNet     Fast  DSI $\alpha=2$, 	 initial_sample_size = [2048, 1024, 512, 256, 128], 	initial cost = 640.0
# 		trial: 0      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.208e-07       true error: 7.728e-09       time 3961            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 5      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.381e-07       true error: 8.078e-10       time 3994            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 10     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 2.225e-07       true error: 3.134e-09       time 4022            sample sizes [4096, 4096, 4096, 256, 128]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 2.005e-07       true error: 7.879e-10       time 4053            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 20     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.178e-07       true error: 1.694e-09       time 4083            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 25     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.552e-07       true error: 2.729e-08       time 4112            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 30     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.352e-07       true error: 1.480e-09       time 4143            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.334e-07       true error: 4.951e-09       time 4173            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 40     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.408e-07       true error: 6.697e-09       time 4204            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 45     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 3.188e-07       true error: 1.407e-08       time 4235            sample sizes [16384, 2048, 2048, 256, 128]
# 	IGP    DNet     Fast  DSI $\alpha=3$, 	 initial_sample_size = [2048, 1024, 512, 256, 128], 	initial cost = 640.0
# 		trial: 0      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.277e-08       true error: 1.438e-09       time 4265            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 5      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.865e-08       true error: 7.778e-10       time 4298            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 10     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.156e-08       true error: 1.063e-10       time 4329            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 4.845e-08       true error: 5.153e-10       time 4360            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 20     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.839e-08       true error: 3.814e-09       time 4392            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 25     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.190e-08       true error: 5.511e-10       time 4424            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 30     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.489e-08       true error: 1.933e-09       time 4454            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.553e-08       true error: 6.032e-09       time 4485            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 40     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 5.950e-08       true error: 1.052e-09       time 4516            sample sizes [4096, 8192, 2048, 256, 128]
# 		trial: 45     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.762e-08       true error: 8.442e-10       time 4548            sample sizes [4096, 4096, 2048, 1024, 256]
# 	IGP    DNet     Fast  DSI $\alpha=4$, 	 initial_sample_size = [2048, 1024, 512, 256, 128], 	initial cost = 640.0
# 		trial: 0      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 4.820e-08       true error: 6.505e-10       time 4578            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 5      iteration: 8      cost: 2048       mean: 1.252e-01       std error: 5.660e-08       true error: 1.208e-09       time 4611            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 10     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 7.977e-08       true error: 3.349e-10       time 4643            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 15     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 4.071e-08       true error: 2.317e-08       time 4674            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 20     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 3.563e-08       true error: 4.547e-10       time 4706            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 25     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 4.254e-08       true error: 1.566e-09       time 4736            sample sizes [4096, 4096, 4096, 256, 128]
# 		trial: 30     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 3.840e-08       true error: 6.495e-10       time 4767            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 35     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 4.803e-08       true error: 2.950e-09       time 4799            sample sizes [4096, 4096, 2048, 1024, 256]
# 		trial: 40     iteration: 8      cost: 2048       mean: 1.252e-01       std error: 1.056e-07       true error: 1.433e-09       time 4831            sample sizes [8192, 4096, 2048, 512, 256]
# 		trial: 45     iteration: 6      cost: 2048       mean: 1.252e-01       std error: 5.653e-08       true error: 2.276e-08       time 4862            sample sizes [4096, 4096, 4096, 256, 128]
#
# budget = 4096, initial budget = 1024
# 	MLMC    IID, 	 initial_sample_size = [4096, 2048, 1024, 512, 256], 	initial cost = 1280.0
# 		trial: 0      iteration: 6      cost: 4096       mean: 1.252e-01       std error: 3.284e-05       true error: 4.466e-06       time 4894            sample sizes [32768, 8192, 2048, 512, 256]
# 		trial: 5      iteration: 6      cost: 4096       mean: 1.252e-01       std error: 3.284e-05       true error: 2.785e-06       time 4923            sample sizes [32768, 8192, 2048, 512, 256]
# 		trial: 10     iteration: 6      cost: 4096       mean: 1.252e-01       std error: 3.263e-05       true error: 3.049e-06       time 4951            sample sizes [32768, 8192, 2048, 512, 256]
# 		trial: 15     iteration: 6      cost: 4096       mean: 1.252e-01       std error: 3.283e-05       true error: 1.253e-05       time 4979            sample sizes [32768, 8192, 2048, 512, 256]
# 		trial: 20     iteration: 6      cost: 4096       mean: 1.253e-01       std error: 3.271e-05       true error: 4.792e-05       time 5008            sample sizes [32768, 8192, 2048, 512, 256]
# 		trial: 25     iteration: 6      cost: 4096       mean: 1.253e-01       std error: 3.263e-05       true error: 3.632e-05       time 5037            sample sizes [32768, 8192, 2048, 512, 256]
# 		trial: 30     iteration: 6      cost: 4096       mean: 1.252e-01       std error: 3.283e-05       true error: 5.605e-06       time 5065            sample sizes [32768, 8192, 2048, 512, 256]
# 		trial: 35     iteration: 6      cost: 4096       mean: 1.253e-01       std error: 3.277e-05       true error: 2.465e-05       time 5093            sample sizes [32768, 8192, 2048, 512, 256]
# 		trial: 40     iteration: 6      cost: 4096       mean: 1.253e-01       std error: 3.271e-05       true error: 3.193e-05       time 5121            sample sizes [32768, 8192, 2048, 512, 256]
# 		trial: 45     iteration: 6      cost: 4096       mean: 1.252e-01       std error: 3.265e-05       true error: 3.848e-05       time 5150            sample sizes [32768, 8192, 2048, 512, 256]
# 	R-MLQMC DNet $R=8$, 	 initial_sample_size = [512, 256, 128, 64, 32], 	initial cost = 1280.0
# 		trial: 0      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.840e-08       true error: 1.924e-08       time 5179            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 5      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.203e-08       true error: 5.876e-09       time 5210            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 10     iteration: 7      cost: 4096       mean: 1.252e-01       std error: 1.928e-08       true error: 3.190e-09       time 5240            sample sizes [8192, 16384, 2048, 1024, 512]
# 		trial: 15     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 1.377e-08       true error: 2.532e-09       time 5271            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 20     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.243e-08       true error: 2.703e-08       time 5302            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 25     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 1.843e-08       true error: 5.925e-09       time 5333            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 30     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.103e-08       true error: 2.928e-08       time 5363            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 35     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 1.504e-08       true error: 2.563e-08       time 5394            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 40     iteration: 6      cost: 4096       mean: 1.252e-01       std error: 7.308e-08       true error: 7.963e-08       time 5425            sample sizes [4096, 16384, 4096, 1024, 256]
# 		trial: 45     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.382e-08       true error: 1.723e-08       time 5455            sample sizes [8192, 8192, 4096, 2048, 512]
# 	R-MLQMC DNet $R=16$, 	 initial_sample_size = [256, 128, 64, 32, 16], 	initial cost = 1280.0
# 		trial: 0      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.495e-08       true error: 7.665e-08       time 5486            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 5      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 3.474e-08       true error: 3.797e-08       time 5517            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 10     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.006e-08       true error: 2.717e-08       time 5548            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 15     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.970e-08       true error: 1.138e-08       time 5579            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 20     iteration: 7      cost: 4096       mean: 1.252e-01       std error: 7.220e-08       true error: 5.420e-08       time 5610            sample sizes [8192, 16384, 2048, 1024, 512]
# 		trial: 25     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.764e-08       true error: 3.835e-08       time 5641            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 30     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.601e-08       true error: 2.905e-09       time 5672            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 35     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.593e-08       true error: 1.202e-08       time 5703            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 40     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.808e-08       true error: 3.901e-09       time 5734            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 45     iteration: 7      cost: 4096       mean: 1.252e-01       std error: 7.369e-08       true error: 1.184e-07       time 5765            sample sizes [8192, 16384, 2048, 1024, 512]
# 	R-MLQMC DNet $R=32$, 	 initial_sample_size = [128, 64, 32, 16, 8], 	initial cost = 1280.0
# 		trial: 0      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 1.865e-07       true error: 4.432e-08       time 5797            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 5      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 9.628e-08       true error: 9.689e-08       time 5828            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 10     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 6.784e-08       true error: 7.860e-10       time 5859            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 15     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 6.095e-08       true error: 8.944e-08       time 5890            sample sizes [8192, 8192, 4096, 2048, 512]
# 		trial: 20     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 1.181e-07       true error: 4.196e-08       time 5921            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 25     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 1.335e-07       true error: 6.288e-08       time 5953            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 30     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 6.984e-08       true error: 4.715e-08       time 5983            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 35     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 1.614e-07       true error: 1.772e-07       time 6014            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 40     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 8.306e-08       true error: 1.000e-07       time 6045            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 45     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 6.568e-08       true error: 2.078e-08       time 6077            sample sizes [16384, 8192, 4096, 1024, 512]
# 	R-MLQMC DNet $R=64$, 	 initial_sample_size = [64, 32, 16, 8, 4], 	initial cost = 1280.0
# 		trial: 0      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.813e-07       true error: 2.765e-07       time 6107            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 5      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 1.577e-07       true error: 1.833e-07       time 6138            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 10     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.049e-07       true error: 2.337e-07       time 6169            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 15     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.053e-07       true error: 1.357e-07       time 6201            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 20     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.114e-07       true error: 7.312e-08       time 6232            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 25     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 3.127e-07       true error: 4.095e-08       time 6263            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 30     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 2.953e-07       true error: 1.151e-08       time 6295            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 35     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 3.221e-07       true error: 6.516e-07       time 6326            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 40     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 3.066e-07       true error: 3.088e-07       time 6358            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 45     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 3.445e-07       true error: 4.710e-08       time 6389            sample sizes [16384, 8192, 4096, 1024, 512]
# 	IGP    DNet     Fast  DSI $\alpha=1$, 	 initial_sample_size = [4096, 2048, 1024, 512, 256], 	initial cost = 1280.0
# 		trial: 0      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.712e-08       true error: 1.975e-10       time 6422            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 5      iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.709e-08       true error: 1.355e-09       time 6459            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 10     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.838e-08       true error: 1.248e-10       time 6497            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 15     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.741e-08       true error: 1.208e-10       time 6535            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 20     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.749e-08       true error: 3.299e-09       time 6572            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 25     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.753e-08       true error: 1.412e-09       time 6609            sample sizes [16384, 8192, 4096, 1024, 512]
# 		trial: 30     iteration: 8      cost: 4096       mean: 1.252e-01       std error: 4.754e-08       true error: 1.541e-09       time 6647            sample sizes [16384, 8192, 4096, 1024, 512]
# ...
# 		trial: 15     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.058e-09       true error: 5.235e-10       time 12731           sample sizes [65536, 32768, 8192, 8192, 2048]
# 		trial: 20     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.892e-09       true error: 3.825e-10       time 12786           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 25     iteration: 7      cost: 16384      mean: 1.252e-01       std error: 1.785e-09       true error: 4.063e-10       time 12838           sample sizes [32768, 16384, 8192, 16384, 2048]
# 		trial: 30     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.328e-09       true error: 1.145e-09       time 12892           sample sizes [65536, 32768, 8192, 8192, 2048]
# 		trial: 35     iteration: 6      cost: 16384      mean: 1.252e-01       std error: 2.640e-09       true error: 2.334e-09       time 12947           sample sizes [16384, 65536, 8192, 8192, 1024]
# 		trial: 40     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 6.581e-10       true error: 1.465e-10       time 13003           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 45     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.100e-09       true error: 1.178e-09       time 13058           sample sizes [32768, 32768, 16384, 8192, 2048]
# 	R-MLQMC DNet $R=16$, 	 initial_sample_size = [1024, 512, 256, 128, 64], 	initial cost = 5120.0
# 		trial: 0      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.180e-08       true error: 2.399e-09       time 13113           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 5      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 6.963e-09       true error: 6.655e-09       time 13168           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 10     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 6.375e-09       true error: 7.574e-09       time 13221           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 15     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 6.963e-09       true error: 5.312e-09       time 13275           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 20     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.322e-09       true error: 9.633e-09       time 13332           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 25     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 5.477e-09       true error: 3.034e-09       time 13386           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 30     iteration: 6      cost: 16384      mean: 1.252e-01       std error: 5.068e-09       true error: 9.175e-10       time 13441           sample sizes [16384, 32768, 32768, 4096, 1024]
# 		trial: 35     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 4.590e-09       true error: 4.656e-09       time 13496           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 40     iteration: 7      cost: 16384      mean: 1.252e-01       std error: 3.726e-09       true error: 9.675e-09       time 13552           sample sizes [32768, 16384, 32768, 4096, 2048]
# 		trial: 45     iteration: 7      cost: 16384      mean: 1.252e-01       std error: 4.845e-09       true error: 6.556e-12       time 13607           sample sizes [32768, 16384, 32768, 4096, 2048]
# 	R-MLQMC DNet $R=32$, 	 initial_sample_size = [512, 256, 128, 64, 32], 	initial cost = 5120.0
# 		trial: 0      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 6.327e-09       true error: 1.063e-08       time 13662           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 5      iteration: 7      cost: 16384      mean: 1.252e-01       std error: 1.844e-08       true error: 1.373e-08       time 13718           sample sizes [131072, 16384, 8192, 4096, 2048]
# 		trial: 10     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 9.651e-09       true error: 2.282e-09       time 13775           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 15     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.245e-08       true error: 5.965e-09       time 13831           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 20     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.103e-08       true error: 1.388e-08       time 13886           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 25     iteration: 7      cost: 16384      mean: 1.252e-01       std error: 3.374e-08       true error: 3.635e-08       time 13944           sample sizes [131072, 16384, 8192, 4096, 2048]
# 		trial: 30     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 9.635e-09       true error: 2.013e-08       time 14000           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 35     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.334e-08       true error: 1.859e-08       time 14056           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 40     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.082e-08       true error: 5.369e-10       time 14112           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 45     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.297e-08       true error: 4.201e-10       time 14168           sample sizes [65536, 32768, 16384, 4096, 2048]
# 	R-MLQMC DNet $R=64$, 	 initial_sample_size = [256, 128, 64, 32, 16], 	initial cost = 5120.0
# 		trial: 0      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.878e-08       true error: 1.549e-09       time 14225           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 5      iteration: 7      cost: 16384      mean: 1.252e-01       std error: 2.772e-08       true error: 1.790e-08       time 14282           sample sizes [32768, 65536, 8192, 4096, 2048]
# 		trial: 10     iteration: 7      cost: 16384      mean: 1.252e-01       std error: 3.063e-08       true error: 1.378e-09       time 14340           sample sizes [32768, 65536, 8192, 4096, 2048]
# 		trial: 15     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.963e-08       true error: 1.462e-08       time 14396           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 20     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.680e-08       true error: 6.371e-09       time 14454           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 25     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.780e-08       true error: 2.412e-08       time 14510           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 30     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.147e-08       true error: 7.676e-09       time 14568           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 35     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.160e-08       true error: 2.138e-08       time 14625           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 40     iteration: 6      cost: 16384      mean: 1.252e-01       std error: 4.421e-08       true error: 3.149e-08       time 14682           sample sizes [131072, 32768, 8192, 2048, 1024]
# 		trial: 45     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.648e-08       true error: 8.044e-09       time 14738           sample sizes [32768, 32768, 16384, 8192, 2048]
# 	IGP    DNet     Fast  DSI $\alpha=1$, 	 initial_sample_size = [16384, 8192, 4096, 2048, 1024], 	initial cost = 5120.0
# 		trial: 0      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.171e-09       true error: 4.360e-11       time 14797           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 5      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.215e-09       true error: 2.063e-11       time 14868           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 10     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 8.383e-09       true error: 9.908e-10       time 14940           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 15     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.121e-09       true error: 2.838e-10       time 15012           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 20     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.215e-09       true error: 1.486e-10       time 15083           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 25     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.206e-09       true error: 1.052e-10       time 15155           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 30     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.192e-09       true error: 3.757e-11       time 15226           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 35     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.210e-09       true error: 9.729e-11       time 15298           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 40     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.219e-09       true error: 7.926e-11       time 15370           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 45     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.198e-09       true error: 2.328e-11       time 15441           sample sizes [65536, 32768, 16384, 4096, 2048]
# 	IGP    DNet     Fast  DSI $\alpha=2$, 	 initial_sample_size = [16384, 8192, 4096, 2048, 1024], 	initial cost = 5120.0
# 		trial: 0      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.294e-08       true error: 1.502e-10       time 15514           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 5      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.278e-08       true error: 2.512e-11       time 15584           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 10     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.015e-08       true error: 8.033e-11       time 15655           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 15     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.278e-08       true error: 1.162e-11       time 15723           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 20     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.660e-08       true error: 3.986e-10       time 15793           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 25     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 7.711e-09       true error: 1.964e-10       time 15864           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 30     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.642e-08       true error: 1.525e-10       time 15933           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 35     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.761e-08       true error: 2.100e-11       time 16003           sample sizes [65536, 32768, 8192, 8192, 2048]
# 		trial: 40     iteration: 7      cost: 16384      mean: 1.252e-01       std error: 1.857e-08       true error: 1.069e-10       time 16072           sample sizes [32768, 16384, 8192, 16384, 2048]
# 		trial: 45     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 8.167e-09       true error: 5.612e-11       time 16144           sample sizes [65536, 32768, 16384, 4096, 2048]
# 	IGP    DNet     Fast  DSI $\alpha=3$, 	 initial_sample_size = [16384, 8192, 4096, 2048, 1024], 	initial cost = 5120.0
# 		trial: 0      iteration: 7      cost: 16384      mean: 1.252e-01       std error: 5.217e-09       true error: 2.622e-10       time 16213           sample sizes [32768, 65536, 8192, 4096, 2048]
# 		trial: 5      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 3.002e-09       true error: 1.673e-10       time 16284           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 10     iteration: 7      cost: 16384      mean: 1.252e-01       std error: 8.299e-09       true error: 9.271e-10       time 16351           sample sizes [32768, 16384, 32768, 4096, 2048]
# 		trial: 15     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.981e-09       true error: 1.282e-10       time 16420           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 20     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 3.346e-09       true error: 1.171e-10       time 16492           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 25     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 4.931e-09       true error: 2.726e-10       time 16561           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 30     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.633e-09       true error: 6.655e-11       time 16635           sample sizes [32768, 32768, 16384, 4096, 4096]
# 		trial: 35     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.624e-09       true error: 1.209e-10       time 16704           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 40     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 3.079e-09       true error: 2.850e-11       time 16772           sample sizes [32768, 32768, 16384, 4096, 4096]
# 		trial: 45     iteration: 7      cost: 16384      mean: 1.252e-01       std error: 4.435e-09       true error: 1.460e-10       time 16844           sample sizes [32768, 65536, 8192, 4096, 2048]
# 	IGP    DNet     Fast  DSI $\alpha=4$, 	 initial_sample_size = [16384, 8192, 4096, 2048, 1024], 	initial cost = 5120.0
# 		trial: 0      iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.474e-09       true error: 1.904e-12       time 16913           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 5      iteration: 6      cost: 16384      mean: 1.252e-01       std error: 4.966e-09       true error: 2.380e-10       time 16982           sample sizes [65536, 16384, 32768, 2048, 1024]
# 		trial: 10     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 1.653e-09       true error: 4.082e-11       time 17053           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 15     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.590e-09       true error: 7.290e-12       time 17121           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 20     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.639e-09       true error: 1.172e-12       time 17192           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 25     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 4.763e-09       true error: 9.923e-11       time 17265           sample sizes [65536, 32768, 16384, 4096, 2048]
# 		trial: 30     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.390e-09       true error: 4.712e-10       time 17335           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 35     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 4.926e-09       true error: 2.458e-10       time 17408           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 40     iteration: 8      cost: 16384      mean: 1.252e-01       std error: 2.741e-09       true error: 1.263e-10       time 17479           sample sizes [32768, 32768, 16384, 8192, 2048]
# 		trial: 45     iteration: 6      cost: 16384      mean: 1.252e-01       std error: 3.228e-09       true error: 1.369e-10       time 17548           sample sizes [16384, 32768, 32768, 4096, 1024]

# %% [markdown]
# ## Analysis

# %%
fig,ax = pyplot.subplots(nrows=1,ncols=1,figsize=(9,5))
for i,name in enumerate(names):
    vals = costs[i]-max_budgets[:,None]
    q_low = np.nanquantile(vals,.1,axis=1)
    q_med = np.nanquantile(vals,.5,axis=1)
    q_high = np.nanquantile(vals,.9,axis=1)
    ax.plot(max_budgets,q_med,'-o',label=name,linewidth=LW,color=COLORS[i])
    ax.fill_between(max_budgets,q_low,q_high,alpha=alpha,color=COLORS[i])
ax.legend(frameon=False,fontsize="large",bbox_to_anchor=(-.25,1))
ax.set_xlabel("max_budgets",fontsize="large")
ax.set_ylabel("median (max_budget - costs)",fontsize="large")
print("above 0 means it is over budget, below 0 means it is within the budget")
# Out:
# above 0 means it is over budget, below 0 means it is within the budget

# %%
nrows = len(max_budgets)
ncols = len(names)
fig,ax = pyplot.subplots(nrows=nrows,ncols=ncols,figsize=(6*ncols,5*nrows),sharey="row",sharex=True)
for i in range(nrows):
    for j in range(ncols):
        bplot = ax[i,j].boxplot(samples_per_level[j,i,:,:],orientation="vertical",label=names[j],patch_artist=True,notch=False)
        for _attr in ['boxes','means']:
            for patch in bplot[_attr]:
                patch.set_facecolor(COLORS[j])
        for _attr in ['medians','fliers','whiskers','medians','means','boxes']:
            for patch in bplot[_attr]:
                patch.set_color(COLORS[j])
    ax[i,0].set_ylabel("budget = %d"%max_budgets[i],fontsize="xx-large")
for j in range(ncols):
    ax[0,j].set_title(names[j],fontsize="xx-large")
    ax[-1,j].set_xlabel("level")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize="xx-large")
#fig.tight_layout()
fig.savefig(dataroot+"sample_allocation.pdf",transparent=True,bbox_inches="tight")

# %%
fig,ax = pyplot.subplots(nrows=1,ncols=2,figsize=(5*2,5),sharey=True,sharex=True)
for i,name in enumerate(names):
    for j,(vals,linestyle,alpha) in enumerate(zip([true_errors[i],std_errors[i]],['-o','--o'],[.1,.2])):
        q_low = np.nanquantile(vals,.25,axis=1)
        q_med = np.nanquantile(vals,.5,axis=1)
        q_high = np.nanquantile(vals,.75,axis=1)
        ax[j].plot(max_budgets,q_med,linestyle,label=name,linewidth=LW,alpha=1,color=COLORS[i])
        #ax[j].scatter(costs[i],vals,color=COLORS[i])
        ax[j].fill_between(max_budgets,q_low,q_high,alpha=alpha,color=COLORS[i])
ax[0].legend(frameon=False,fontsize="large",bbox_to_anchor=(-.5,1))
ax[0].set_yscale("log",base=10)
ax[0].set_xscale("log",base=2)
ax[0].set_ylabel("true_errors",fontsize="large")
ax[1].set_ylabel("standard error")
for j in range(2):
    ax[j].set_xlabel("max_budgets",fontsize="large")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize="large")
fig.savefig(dataroot+"convergence_by_error.pdf",transparent=True,bbox_inches="tight")
fig,ax = pyplot.subplots(nrows=1,ncols=len(names),figsize=(5*len(names),5+1),sharey=True,sharex=True)
for i,name in enumerate(names):
    for j,(error_metric,vals,linestyle,alpha) in enumerate(zip(["true error","standard error"],[true_errors[i],std_errors[i]],['-o','--o'],[.1,.2])):
        q_low = np.nanquantile(vals,.25,axis=1)
        q_med = np.nanquantile(vals,.5,axis=1)
        q_high = np.nanquantile(vals,.75,axis=1)
        ax[i].plot(max_budgets,q_med,linestyle,label=error_metric,linewidth=LW,alpha=1,color=COLORS[i])
        #ax[j].scatter(costs[i],vals,color=COLORS[i])
        ax[i].fill_between(max_budgets,q_low,q_high,alpha=alpha,color=COLORS[i])
        ax[i].set_title(name,fontsize="large")
ax[0].legend(frameon=False,fontsize="large")
ax[0].set_yscale("log",base=10)
ax[0].set_xscale("log",base=2)
for j in range(len(names)):
    ax[j].set_xlabel("max_budgets",fontsize="large")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize="large")
fig.savefig(dataroot+"convergence_by_method.pdf",transparent=True,bbox_inches="tight")

# %%
nrows = len(max_budgets)
ncols = len(names)
ncols = fig,ax = pyplot.subplots(nrows=nrows,ncols=ncols,figsize=(ncols*5,nrows*4),sharex=True,sharey=True)
for i,name in enumerate(names):
    for j in range(len(max_budgets)):
        ax[j,i].hist(np.log10(true_errors[i,j]),label=name,density=True,bins=10,alpha=.5,color=COLORS[i]) 
    ax[0,i].set_title(name,fontsize="x-large")
    ax[-1,i].set_xlabel(r"$\log_{10}(\mathrm{error})$",fontsize="x-large")
for j in range(len(max_budgets)):
    ax[j,0].set_ylabel("budget = %d"%max_budgets[j],fontsize="x-large")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize="x-large")#,ncol=len(names))
#ax[0].set_ylabel("density",fontsize="x-large")
#fig.tight_layout()
#ax[0].set_xscale("log",base=10)
fig.savefig(dataroot+"densities.pdf",transparent=True,bbox_inches="tight")

# %%
ncols = len(names) 
nrows = len(max_budgets)
fig,ax = pyplot.subplots(nrows=nrows,ncols=ncols,figsize=(5*ncols,5*nrows),sharex=True,sharey=True)
for i,name in enumerate(names):
    for j in range(len(max_budgets)):
        ax[j,i].scatter(true_errors[i,j],std_errors[i,j],label=name,color=COLORS[i])
        ax[j,i].axline(xy1=(0,0),slope=1,color="k")
    ax[-1,i].set_ylabel("std errors",fontsize="large")
    ax[0,i].set_title(name,fontsize='x-large')
for j in range(len(max_budgets)):
    ax[j,0].set_ylabel("budget = %d"%max_budgets[j])
ax[0,0].set_xscale("log",base=10)
ax[0,0].set_yscale("log",base=10)
for j in range(len(max_budgets)):
    ax[j,0].set_xlabel("true errors",fontsize="large")
fig.suptitle(r"%s problem with $d = %d$ dimensions and $L = %d$ levels with $T=%d$ trials"%(problem.__name__,dimension,num_levels,trials),fontsize='xx-large')#,ncols=len(max_budgets),)
#ax[j].xaxis.set_tick_params(labelbottom=True)
fig.tight_layout()
fig.savefig(dataroot+"error_scatters.pdf",transparent=True,bbox_inches="tight")
